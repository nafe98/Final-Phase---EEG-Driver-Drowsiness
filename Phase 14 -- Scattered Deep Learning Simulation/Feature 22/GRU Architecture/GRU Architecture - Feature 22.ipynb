# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 22/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 22/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 22/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 22/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - GRU</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from tensorflow.keras.layers import GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for GRU

# %%
X_train_array = X_train  
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (22, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001

# %% [markdown]
# # 2. Define Architecture

# %%
gru_model = Sequential([
    
    GRU(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1),
    GRU(256, activation='relu'),
    Dropout(0.1),
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
gru_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 22, 512)           791040
#
#  dropout (Dropout)           (None, 22, 512)           0
#
#  gru_1 (GRU)                 (None, 256)               591360
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,382,657
# Trainable params: 1,382,657
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
gru_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Integrating Callbacks</h2>
#
# </div>

# %% [markdown]
# ## EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# ## Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/GRU_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = gru_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping], 
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6443 - accuracy: 0.6261
# Epoch 1: val_loss improved from inf to 0.62852, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 955s 1s/step - loss: 0.6443 - accuracy: 0.6261 - val_loss: 0.6285 - val_accuracy: 0.6420
# Epoch 2/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6176 - accuracy: 0.6546
# Epoch 2: val_loss improved from 0.62852 to 0.60409, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 952s 1s/step - loss: 0.6176 - accuracy: 0.6546 - val_loss: 0.6041 - val_accuracy: 0.6671
# Epoch 3/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5912 - accuracy: 0.6785
# Epoch 3: val_loss improved from 0.60409 to 0.59139, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 952s 1s/step - loss: 0.5912 - accuracy: 0.6785 - val_loss: 0.5914 - val_accuracy: 0.6799
# Epoch 4/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5810 - accuracy: 0.6889
# Epoch 4: val_loss did not improve from 0.59139
# 799/799 [==============================] - 952s 1s/step - loss: 0.5810 - accuracy: 0.6889 - val_loss: 0.5978 - val_accuracy: 0.6741
# Epoch 5/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6455 - accuracy: 0.6352
# Epoch 5: val_loss did not improve from 0.59139
# 799/799 [==============================] - 1013s 1s/step - loss: 0.6455 - accuracy: 0.6352 - val_loss: 0.6353 - val_accuracy: 0.6395
# Epoch 6/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6281 - accuracy: 0.6491
# Epoch 6: val_loss did not improve from 0.59139
# 799/799 [==============================] - 1024s 1s/step - loss: 0.6281 - accuracy: 0.6491 - val_loss: 0.6154 - val_accuracy: 0.6584
# Epoch 7/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6180 - accuracy: 0.6581
# Epoch 7: val_loss did not improve from 0.59139
# 799/799 [==============================] - 951s 1s/step - loss: 0.6180 - accuracy: 0.6581 - val_loss: 0.6080 - val_accuracy: 0.6630
# Epoch 8/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6092 - accuracy: 0.6644
# Epoch 8: val_loss did not improve from 0.59139
# 799/799 [==============================] - 952s 1s/step - loss: 0.6092 - accuracy: 0.6644 - val_loss: 0.6010 - val_accuracy: 0.6681
# Epoch 9/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5934 - accuracy: 0.6779
# Epoch 9: val_loss did not improve from 0.59139
# 799/799 [==============================] - 952s 1s/step - loss: 0.5934 - accuracy: 0.6779 - val_loss: 0.6044 - val_accuracy: 0.6678
# Epoch 10/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6535 - accuracy: 0.6069
# Epoch 10: val_loss did not improve from 0.59139
# 799/799 [==============================] - 952s 1s/step - loss: 0.6535 - accuracy: 0.6069 - val_loss: 0.6497 - val_accuracy: 0.6138
# Epoch 11/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6487 - accuracy: 0.6131
# Epoch 11: val_loss did not improve from 0.59139
# 799/799 [==============================] - 952s 1s/step - loss: 0.6487 - accuracy: 0.6131 - val_loss: 0.6349 - val_accuracy: 0.6265
# Epoch 12/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6443 - accuracy: 0.6174
# Epoch 12: val_loss did not improve from 0.59139
# 799/799 [==============================] - 951s 1s/step - loss: 0.6443 - accuracy: 0.6174 - val_loss: 0.6332 - val_accuracy: 0.6285
# Epoch 13/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6314 - accuracy: 0.6320
# Epoch 13: val_loss did not improve from 0.59139
# 799/799 [==============================] - 951s 1s/step - loss: 0.6314 - accuracy: 0.6320 - val_loss: 0.6219 - val_accuracy: 0.6423
# Epoch 14/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6216 - accuracy: 0.6428
# Epoch 14: val_loss did not improve from 0.59139
# 799/799 [==============================] - 951s 1s/step - loss: 0.6216 - accuracy: 0.6428 - val_loss: 0.6131 - val_accuracy: 0.6508
# Epoch 15/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6163 - accuracy: 0.6497
# Epoch 15: val_loss did not improve from 0.59139
# 799/799 [==============================] - 951s 1s/step - loss: 0.6163 - accuracy: 0.6497 - val_loss: 0.6362 - val_accuracy: 0.6285
# Epoch 16/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6386 - accuracy: 0.6263
# Epoch 16: val_loss did not improve from 0.59139
# 799/799 [==============================] - 952s 1s/step - loss: 0.6386 - accuracy: 0.6263 - val_loss: 0.6153 - val_accuracy: 0.6515
# Epoch 17/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6102 - accuracy: 0.6594
# Epoch 17: val_loss did not improve from 0.59139
# 799/799 [==============================] - 951s 1s/step - loss: 0.6102 - accuracy: 0.6594 - val_loss: 0.6002 - val_accuracy: 0.6690
# Epoch 18/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5983 - accuracy: 0.6717
# Epoch 18: val_loss improved from 0.59139 to 0.59078, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 1006s 1s/step - loss: 0.5983 - accuracy: 0.6717 - val_loss: 0.5908 - val_accuracy: 0.6773
# Epoch 19/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5903 - accuracy: 0.6780
# Epoch 19: val_loss improved from 0.59078 to 0.58810, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 952s 1s/step - loss: 0.5903 - accuracy: 0.6780 - val_loss: 0.5881 - val_accuracy: 0.6791
# Epoch 20/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5913 - accuracy: 0.6773
# Epoch 20: val_loss improved from 0.58810 to 0.58674, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 952s 1s/step - loss: 0.5913 - accuracy: 0.6773 - val_loss: 0.5867 - val_accuracy: 0.6787
# Epoch 21/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5879 - accuracy: 0.6813
# Epoch 21: val_loss did not improve from 0.58674
# 799/799 [==============================] - 952s 1s/step - loss: 0.5879 - accuracy: 0.6813 - val_loss: 0.5982 - val_accuracy: 0.6704
# Epoch 22/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6222 - accuracy: 0.6487
# Epoch 22: val_loss did not improve from 0.58674
# 799/799 [==============================] - 951s 1s/step - loss: 0.6222 - accuracy: 0.6487 - val_loss: 0.6808 - val_accuracy: 0.6296
# Epoch 23/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6391 - accuracy: 0.6334
# Epoch 23: val_loss did not improve from 0.58674
# 799/799 [==============================] - 952s 1s/step - loss: 0.6391 - accuracy: 0.6334 - val_loss: 0.6234 - val_accuracy: 0.6499
# Epoch 24/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6616 - accuracy: 0.6062
# Epoch 24: val_loss did not improve from 0.58674
# 799/799 [==============================] - 952s 1s/step - loss: 0.6616 - accuracy: 0.6062 - val_loss: 0.6648 - val_accuracy: 0.6095
# Epoch 25/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6597 - accuracy: 0.6100
# Epoch 25: val_loss did not improve from 0.58674
# 799/799 [==============================] - 952s 1s/step - loss: 0.6597 - accuracy: 0.6100 - val_loss: 0.6612 - val_accuracy: 0.6024
# Epoch 26/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6949 - accuracy: 0.5688
# Epoch 26: val_loss did not improve from 0.58674
# 799/799 [==============================] - 952s 1s/step - loss: 0.6949 - accuracy: 0.5688 - val_loss: 0.6835 - val_accuracy: 0.5703
# Epoch 27/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6801 - accuracy: 0.5697
# Epoch 27: val_loss did not improve from 0.58674
# 799/799 [==============================] - 954s 1s/step - loss: 0.6801 - accuracy: 0.5697 - val_loss: 0.6685 - val_accuracy: 0.5933
# Epoch 28/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6798 - accuracy: 0.5736
# Epoch 28: val_loss did not improve from 0.58674
# 799/799 [==============================] - 951s 1s/step - loss: 0.6798 - accuracy: 0.5736 - val_loss: 0.6714 - val_accuracy: 0.5867
# Epoch 29/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6713 - accuracy: 0.5826
# Epoch 29: val_loss did not improve from 0.58674
# 799/799 [==============================] - 952s 1s/step - loss: 0.6713 - accuracy: 0.5826 - val_loss: 0.6619 - val_accuracy: 0.5981
# Epoch 30/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6645 - accuracy: 0.5918
# Epoch 30: val_loss did not improve from 0.58674
# 799/799 [==============================] - 951s 1s/step - loss: 0.6645 - accuracy: 0.5918 - val_loss: 0.6571 - val_accuracy: 0.6027
# Epoch 31/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6614 - accuracy: 0.5961
# Epoch 31: val_loss did not improve from 0.58674
# 799/799 [==============================] - 951s 1s/step - loss: 0.6614 - accuracy: 0.5961 - val_loss: 0.6542 - val_accuracy: 0.6057
# Epoch 32/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6591 - accuracy: 0.5984
# Epoch 32: val_loss did not improve from 0.58674
# 799/799 [==============================] - 951s 1s/step - loss: 0.6591 - accuracy: 0.5984 - val_loss: 0.6518 - val_accuracy: 0.6101
# Epoch 33/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6548 - accuracy: 0.6041
# Epoch 33: val_loss did not improve from 0.58674
# 799/799 [==============================] - 952s 1s/step - loss: 0.6548 - accuracy: 0.6041 - val_loss: 0.6493 - val_accuracy: 0.6098
# Epoch 34/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6523 - accuracy: 0.6059
# Epoch 34: val_loss did not improve from 0.58674
# 799/799 [==============================] - 951s 1s/step - loss: 0.6523 - accuracy: 0.6059 - val_loss: 0.6471 - val_accuracy: 0.6148
# Epoch 35/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6499 - accuracy: 0.6080
# Epoch 35: val_loss did not improve from 0.58674
# 799/799 [==============================] - 950s 1s/step - loss: 0.6499 - accuracy: 0.6080 - val_loss: 0.6470 - val_accuracy: 0.6106
# Epoch 36/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6476 - accuracy: 0.6108
# Epoch 36: val_loss did not improve from 0.58674
# 799/799 [==============================] - 950s 1s/step - loss: 0.6476 - accuracy: 0.6108 - val_loss: 0.6421 - val_accuracy: 0.6158
# Epoch 37/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6482 - accuracy: 0.6100
# Epoch 37: val_loss did not improve from 0.58674
# 799/799 [==============================] - 950s 1s/step - loss: 0.6482 - accuracy: 0.6100 - val_loss: 0.6414 - val_accuracy: 0.6174
# Epoch 38/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6870 - accuracy: 0.5957
# Epoch 38: val_loss did not improve from 0.58674
# 799/799 [==============================] - 950s 1s/step - loss: 0.6870 - accuracy: 0.5957 - val_loss: 0.6963 - val_accuracy: 0.5708
# Epoch 39/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6862 - accuracy: 0.5697
# Epoch 39: val_loss did not improve from 0.58674
# 799/799 [==============================] - 950s 1s/step - loss: 0.6862 - accuracy: 0.5697 - val_loss: 0.6760 - val_accuracy: 0.5768
# Epoch 40/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6790 - accuracy: 0.5772
# Epoch 40: val_loss did not improve from 0.58674
# 799/799 [==============================] - 950s 1s/step - loss: 0.6790 - accuracy: 0.5772 - val_loss: 0.6753 - val_accuracy: 0.5834
# Epoch 41/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7051 - accuracy: 0.5788
# Epoch 41: val_loss did not improve from 0.58674
# 799/799 [==============================] - 950s 1s/step - loss: 0.7051 - accuracy: 0.5788 - val_loss: 0.6713 - val_accuracy: 0.5888
# Epoch 42/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6725 - accuracy: 0.5839
# Epoch 42: val_loss did not improve from 0.58674
# 799/799 [==============================] - 950s 1s/step - loss: 0.6725 - accuracy: 0.5839 - val_loss: 0.6681 - val_accuracy: 0.5930
# Epoch 43/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6707 - accuracy: 0.5869
# Epoch 43: val_loss did not improve from 0.58674
# 799/799 [==============================] - 950s 1s/step - loss: 0.6707 - accuracy: 0.5869 - val_loss: 0.6673 - val_accuracy: 0.5928
# Epoch 44/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6700 - accuracy: 0.5879
# Epoch 44: val_loss did not improve from 0.58674
# 799/799 [==============================] - 950s 1s/step - loss: 0.6700 - accuracy: 0.5879 - val_loss: 0.6673 - val_accuracy: 0.5916
# Epoch 45/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6702 - accuracy: 0.5878
# Epoch 45: val_loss did not improve from 0.58674
# 799/799 [==============================] - 951s 1s/step - loss: 0.6702 - accuracy: 0.5878 - val_loss: 0.6677 - val_accuracy: 0.5918
# Epoch 46/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6685 - accuracy: 0.5885
# Epoch 46: val_loss did not improve from 0.58674
# 799/799 [==============================] - 950s 1s/step - loss: 0.6685 - accuracy: 0.5885 - val_loss: 0.6665 - val_accuracy: 0.5916
# Epoch 47/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6684 - accuracy: 0.5890
# Epoch 47: val_loss did not improve from 0.58674
# 799/799 [==============================] - 950s 1s/step - loss: 0.6684 - accuracy: 0.5890 - val_loss: 0.6656 - val_accuracy: 0.5949
# Epoch 48/500
# 799/799 [==============================] - ETA: 0s - loss: 1.1343 - accuracy: 0.5760
# Epoch 48: val_loss did not improve from 0.58674
# 799/799 [==============================] - 950s 1s/step - loss: 1.1343 - accuracy: 0.5760 - val_loss: 0.6918 - val_accuracy: 0.5735
# Epoch 49/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7273 - accuracy: 0.5474
# Epoch 49: val_loss did not improve from 0.58674
# 799/799 [==============================] - 950s 1s/step - loss: 0.7273 - accuracy: 0.5474 - val_loss: 0.6868 - val_accuracy: 0.5671
# Epoch 50/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6877 - accuracy: 0.5585
# Epoch 50: val_loss did not improve from 0.58674
# 799/799 [==============================] - 950s 1s/step - loss: 0.6877 - accuracy: 0.5585 - val_loss: 0.6842 - val_accuracy: 0.5652
# Training Time:  47749.64656829834 seconds

# %% [markdown]
# # Saving the model and training history

# %%
gru_model.save('GRU_Architecture_22_Features.h5')
np.save('GRU_history_22_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of GRU Network - 22 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of GRU Network - 22 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for GRU Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[ -0.54725173],
#         [ -6.70051216],
#         [ -3.53210347],
#         ...,
#         [  8.60861546],
#         [ -4.28951879],
#         [ -9.13135839]],
#
#        [[ 15.10660785],
#         [ 12.89015194],
#         [  9.38198263],
#         ...,
#         [  4.13269109],
#         [ 14.32601172],
#         [  6.44332559]],
#
#        [[  2.93699623],
#         [  0.48231236],
#         [  3.60238997],
#         ...,
#         [  5.58703798],
#         [ -0.61380792],
#         [  2.23852673]],
#
#        ...,
#
#        [[ -2.06647329],
#         [ -7.3330383 ],
#         [ -3.58371377],
#         ...,
#         [  0.27504944],
#         [ -4.5999193 ],
#         [ -7.61533117]],
#
#        [[ 22.22658066],
#         [ 25.39460655],
#         [ 14.46520722],
#         ...,
#         [  8.9143928 ],
#         [ 30.56053823],
#         [ 30.75069401]],
#
#        [[-11.09871642],
#         [ -3.76626649],
#         [ -0.32644541],
#         ...,
#         [ -7.83639415],
#         [ -7.83041613],
#         [ -7.26435187]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = gru_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 194s 40ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = gru_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.68, Test loss: 0.58

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.70      0.69     77586
#            1       0.69      0.67      0.68     77704
#
#     accuracy                           0.68    155290
#    macro avg       0.68      0.68      0.68    155290
# weighted avg       0.68      0.68      0.68    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix GRU - 22 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.6829222744542469
# Precision: 0.6885324078366958
# Recall: 0.6689230927622773
# F1-score: 0.6785861157348477
# AUC-ROC: 0.7540942757664391

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['GRU - 22'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()

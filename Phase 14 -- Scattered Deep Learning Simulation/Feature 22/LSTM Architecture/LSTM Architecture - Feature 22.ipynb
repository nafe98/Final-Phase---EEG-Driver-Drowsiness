# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 22/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 22/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 22/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 22/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - LSTM</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
from keras.layers import LSTM
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for LSTM

# %%
X_train_array = X_train  
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (22, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001

# %% [markdown]
# # 2. Define Architecture

# %%
lstm_model = Sequential([
    
    LSTM(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1), 
    LSTM(256, activation='relu'),
    Dropout(0.1),  
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 22, 512)           1052672
#
#  dropout (Dropout)           (None, 22, 512)           0
#
#  lstm_1 (LSTM)               (None, 256)               787456
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,840,385
# Trainable params: 1,840,385
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
lstm_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# ## Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/LSTM_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = lstm_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping],  
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6562 - accuracy: 0.6247
# Epoch 1: val_loss improved from inf to 0.63527, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 908s 1s/step - loss: 0.6562 - accuracy: 0.6247 - val_loss: 0.6353 - val_accuracy: 0.6330
# Epoch 2/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6253 - accuracy: 0.6461
# Epoch 2: val_loss improved from 0.63527 to 0.62221, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 903s 1s/step - loss: 0.6253 - accuracy: 0.6461 - val_loss: 0.6222 - val_accuracy: 0.6490
# Epoch 3/500
# 799/799 [==============================] - ETA: 0s - loss: 1.0766 - accuracy: 0.6053
# Epoch 3: val_loss did not improve from 0.62221
# 799/799 [==============================] - 903s 1s/step - loss: 1.0766 - accuracy: 0.6053 - val_loss: 0.6757 - val_accuracy: 0.5755
# Epoch 4/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6747 - accuracy: 0.5796
# Epoch 4: val_loss did not improve from 0.62221
# 799/799 [==============================] - 902s 1s/step - loss: 0.6747 - accuracy: 0.5796 - val_loss: 0.6646 - val_accuracy: 0.5951
# Epoch 5/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7050 - accuracy: 0.5850
# Epoch 5: val_loss did not improve from 0.62221
# 799/799 [==============================] - 903s 1s/step - loss: 0.7050 - accuracy: 0.5850 - val_loss: 0.6744 - val_accuracy: 0.5782
# Epoch 6/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6667 - accuracy: 0.5953
# Epoch 6: val_loss did not improve from 0.62221
# 799/799 [==============================] - 901s 1s/step - loss: 0.6667 - accuracy: 0.5953 - val_loss: 0.6665 - val_accuracy: 0.5926
# Epoch 7/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6615 - accuracy: 0.6019
# Epoch 7: val_loss did not improve from 0.62221
# 799/799 [==============================] - 901s 1s/step - loss: 0.6615 - accuracy: 0.6019 - val_loss: 0.6587 - val_accuracy: 0.6125
# Epoch 8/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7497 - accuracy: 0.5717
# Epoch 8: val_loss did not improve from 0.62221
# 799/799 [==============================] - 902s 1s/step - loss: 0.7497 - accuracy: 0.5717 - val_loss: 0.6728 - val_accuracy: 0.5816
# Epoch 9/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6706 - accuracy: 0.5840
# Epoch 9: val_loss did not improve from 0.62221
# 799/799 [==============================] - 901s 1s/step - loss: 0.6706 - accuracy: 0.5840 - val_loss: 0.6649 - val_accuracy: 0.5895
# Epoch 10/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6659 - accuracy: 0.5904
# Epoch 10: val_loss did not improve from 0.62221
# 799/799 [==============================] - 901s 1s/step - loss: 0.6659 - accuracy: 0.5904 - val_loss: 0.6604 - val_accuracy: 0.5963
# Epoch 11/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6662 - accuracy: 0.5937
# Epoch 11: val_loss did not improve from 0.62221
# 799/799 [==============================] - 901s 1s/step - loss: 0.6662 - accuracy: 0.5937 - val_loss: 0.6612 - val_accuracy: 0.5975
# Epoch 12/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6697 - accuracy: 0.5881
# Epoch 12: val_loss did not improve from 0.62221
# 799/799 [==============================] - 901s 1s/step - loss: 0.6697 - accuracy: 0.5881 - val_loss: 0.6653 - val_accuracy: 0.5944
# Epoch 13/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6879 - accuracy: 0.5879
# Epoch 13: val_loss did not improve from 0.62221
# 799/799 [==============================] - 902s 1s/step - loss: 0.6879 - accuracy: 0.5879 - val_loss: 0.6863 - val_accuracy: 0.5669
# Epoch 14/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6797 - accuracy: 0.5774
# Epoch 14: val_loss did not improve from 0.62221
# 799/799 [==============================] - 902s 1s/step - loss: 0.6797 - accuracy: 0.5774 - val_loss: 0.6686 - val_accuracy: 0.5890
# Epoch 15/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6709 - accuracy: 0.5856
# Epoch 15: val_loss did not improve from 0.62221
# 799/799 [==============================] - 901s 1s/step - loss: 0.6709 - accuracy: 0.5856 - val_loss: 0.6638 - val_accuracy: 0.5969
# Epoch 16/500
# 799/799 [==============================] - ETA: 0s - loss: 2.6668 - accuracy: 0.5730
# Epoch 16: val_loss did not improve from 0.62221
# 799/799 [==============================] - 901s 1s/step - loss: 2.6668 - accuracy: 0.5730 - val_loss: 0.6785 - val_accuracy: 0.5715
# Epoch 17/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6876 - accuracy: 0.5745
# Epoch 17: val_loss did not improve from 0.62221
# 799/799 [==============================] - 901s 1s/step - loss: 0.6876 - accuracy: 0.5745 - val_loss: 0.6743 - val_accuracy: 0.5791
# Epoch 18/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6785 - accuracy: 0.5797
# Epoch 18: val_loss did not improve from 0.62221
# 799/799 [==============================] - 901s 1s/step - loss: 0.6785 - accuracy: 0.5797 - val_loss: 0.6703 - val_accuracy: 0.5855
# Epoch 19/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6728 - accuracy: 0.5829
# Epoch 19: val_loss did not improve from 0.62221
# 799/799 [==============================] - 901s 1s/step - loss: 0.6728 - accuracy: 0.5829 - val_loss: 0.6689 - val_accuracy: 0.5872
# Epoch 20/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6892 - accuracy: 0.5845
# Epoch 20: val_loss did not improve from 0.62221
# 799/799 [==============================] - 901s 1s/step - loss: 0.6892 - accuracy: 0.5845 - val_loss: 0.6668 - val_accuracy: 0.5916
# Epoch 21/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6703 - accuracy: 0.5868
# Epoch 21: val_loss did not improve from 0.62221
# 799/799 [==============================] - 902s 1s/step - loss: 0.6703 - accuracy: 0.5868 - val_loss: 0.6655 - val_accuracy: 0.5942
# Epoch 22/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6702 - accuracy: 0.5882
# Epoch 22: val_loss did not improve from 0.62221
# 799/799 [==============================] - 901s 1s/step - loss: 0.6702 - accuracy: 0.5882 - val_loss: 0.6677 - val_accuracy: 0.5905
# Epoch 23/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6764 - accuracy: 0.5907
# Epoch 23: val_loss did not improve from 0.62221
# 799/799 [==============================] - 901s 1s/step - loss: 0.6764 - accuracy: 0.5907 - val_loss: 0.6612 - val_accuracy: 0.5991
# Epoch 24/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6677 - accuracy: 0.5924
# Epoch 24: val_loss did not improve from 0.62221
# 799/799 [==============================] - 902s 1s/step - loss: 0.6677 - accuracy: 0.5924 - val_loss: 0.6614 - val_accuracy: 0.5984
# Epoch 25/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6641 - accuracy: 0.5951
# Epoch 25: val_loss did not improve from 0.62221
# 799/799 [==============================] - 902s 1s/step - loss: 0.6641 - accuracy: 0.5951 - val_loss: 0.6570 - val_accuracy: 0.6036
# Epoch 26/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6597 - accuracy: 0.6003
# Epoch 26: val_loss did not improve from 0.62221
# 799/799 [==============================] - 902s 1s/step - loss: 0.6597 - accuracy: 0.6003 - val_loss: 0.6546 - val_accuracy: 0.6062
# Epoch 27/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6646 - accuracy: 0.5945
# Epoch 27: val_loss did not improve from 0.62221
# 799/799 [==============================] - 902s 1s/step - loss: 0.6646 - accuracy: 0.5945 - val_loss: 0.6590 - val_accuracy: 0.6029
# Epoch 28/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6635 - accuracy: 0.5977
# Epoch 28: val_loss did not improve from 0.62221
# 799/799 [==============================] - 902s 1s/step - loss: 0.6635 - accuracy: 0.5977 - val_loss: 0.6529 - val_accuracy: 0.6113
# Epoch 29/500
# 799/799 [==============================] - ETA: 0s - loss: 115.7410 - accuracy: 0.5621
# Epoch 29: val_loss did not improve from 0.62221
# 799/799 [==============================] - 902s 1s/step - loss: 115.7410 - accuracy: 0.5621 - val_loss: 0.6821 - val_accuracy: 0.5694
# Epoch 30/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6818 - accuracy: 0.5664
# Epoch 30: val_loss did not improve from 0.62221
# 799/799 [==============================] - 901s 1s/step - loss: 0.6818 - accuracy: 0.5664 - val_loss: 0.6767 - val_accuracy: 0.5782
# Epoch 31/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6781 - accuracy: 0.5738
# Epoch 31: val_loss did not improve from 0.62221
# 799/799 [==============================] - 902s 1s/step - loss: 0.6781 - accuracy: 0.5738 - val_loss: 0.6741 - val_accuracy: 0.5840
# Epoch 32/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6765 - accuracy: 0.5777
# Epoch 32: val_loss did not improve from 0.62221
# 799/799 [==============================] - 901s 1s/step - loss: 0.6765 - accuracy: 0.5777 - val_loss: 0.6722 - val_accuracy: 0.5872
# Training Time:  28857.595715761185 seconds

# %% [markdown]
# # Saving the model and training history

# %%
lstm_model.save('LSTM_Architecture_22_Features.h5')
np.save('LSTM_history_22_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of LSTM Neural Network - 22 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of LSTM Neural Network - 22 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for LSTM Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[ -0.54725173],
#         [ -6.70051216],
#         [ -3.53210347],
#         ...,
#         [  8.60861546],
#         [ -4.28951879],
#         [ -9.13135839]],
#
#        [[ 15.10660785],
#         [ 12.89015194],
#         [  9.38198263],
#         ...,
#         [  4.13269109],
#         [ 14.32601172],
#         [  6.44332559]],
#
#        [[  2.93699623],
#         [  0.48231236],
#         [  3.60238997],
#         ...,
#         [  5.58703798],
#         [ -0.61380792],
#         [  2.23852673]],
#
#        ...,
#
#        [[ -2.06647329],
#         [ -7.3330383 ],
#         [ -3.58371377],
#         ...,
#         [  0.27504944],
#         [ -4.5999193 ],
#         [ -7.61533117]],
#
#        [[ 22.22658066],
#         [ 25.39460655],
#         [ 14.46520722],
#         ...,
#         [  8.9143928 ],
#         [ 30.56053823],
#         [ 30.75069401]],
#
#        [[-11.09871642],
#         [ -3.76626649],
#         [ -0.32644541],
#         ...,
#         [ -7.83639415],
#         [ -7.83041613],
#         [ -7.26435187]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = lstm_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 182s 37ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = lstm_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.65, Test loss: 0.62

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.74      0.68     77586
#            1       0.69      0.57      0.62     77704
#
#     accuracy                           0.65    155290
#    macro avg       0.66      0.65      0.65    155290
# weighted avg       0.66      0.65      0.65    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix LSTM - 22 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.6545044754974564
# Precision: 0.6869888360232609
# Recall: 0.5686065067435396
# F1-score: 0.6222169020828345
# AUC-ROC: 0.7127057930639672

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['LSTM - 22'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()

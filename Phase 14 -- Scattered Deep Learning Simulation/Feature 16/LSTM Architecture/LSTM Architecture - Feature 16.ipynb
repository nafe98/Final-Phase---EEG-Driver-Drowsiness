# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 16/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 16/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 16/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 16/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - LSTM</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
from keras.layers import LSTM
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for LSTM

# %%
X_train_array = X_train  
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (16, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001

# %% [markdown]
# # 2. Define Architecture

# %%
lstm_model = Sequential([
    
    LSTM(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1), 
    LSTM(256, activation='relu'),
    Dropout(0.1),  
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 16, 512)           1052672
#
#  dropout (Dropout)           (None, 16, 512)           0
#
#  lstm_1 (LSTM)               (None, 256)               787456
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,840,385
# Trainable params: 1,840,385
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
lstm_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# ## Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/LSTM_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = lstm_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping],  
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6476 - accuracy: 0.6206
# Epoch 1: val_loss improved from inf to 0.63737, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 666s 830ms/step - loss: 0.6476 - accuracy: 0.6206 - val_loss: 0.6374 - val_accuracy: 0.6277
# Epoch 2/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6309 - accuracy: 0.6414
# Epoch 2: val_loss improved from 0.63737 to 0.62174, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 662s 828ms/step - loss: 0.6309 - accuracy: 0.6414 - val_loss: 0.6217 - val_accuracy: 0.6508
# Epoch 3/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6093 - accuracy: 0.6624
# Epoch 3: val_loss improved from 0.62174 to 0.60073, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 662s 828ms/step - loss: 0.6093 - accuracy: 0.6624 - val_loss: 0.6007 - val_accuracy: 0.6677
# Epoch 4/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6107 - accuracy: 0.6664
# Epoch 4: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 827ms/step - loss: 0.6107 - accuracy: 0.6664 - val_loss: 0.6958 - val_accuracy: 0.5553
# Epoch 5/500
# 799/799 [==============================] - ETA: 0s - loss: 0.9281 - accuracy: 0.5940
# Epoch 5: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 828ms/step - loss: 0.9281 - accuracy: 0.5940 - val_loss: 0.7022 - val_accuracy: 0.5015
# Epoch 6/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6912 - accuracy: 0.5609
# Epoch 6: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 828ms/step - loss: 0.6912 - accuracy: 0.5609 - val_loss: 0.6784 - val_accuracy: 0.5770
# Epoch 7/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6797 - accuracy: 0.5763
# Epoch 7: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 827ms/step - loss: 0.6797 - accuracy: 0.5763 - val_loss: 0.6731 - val_accuracy: 0.5836
# Epoch 8/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6733 - accuracy: 0.5817
# Epoch 8: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 828ms/step - loss: 0.6733 - accuracy: 0.5817 - val_loss: 0.6704 - val_accuracy: 0.5868
# Epoch 9/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6716 - accuracy: 0.5845
# Epoch 9: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 827ms/step - loss: 0.6716 - accuracy: 0.5845 - val_loss: 0.6694 - val_accuracy: 0.5895
# Epoch 10/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6758 - accuracy: 0.5843
# Epoch 10: val_loss did not improve from 0.60073
# 799/799 [==============================] - 662s 828ms/step - loss: 0.6758 - accuracy: 0.5843 - val_loss: 0.6698 - val_accuracy: 0.5879
# Epoch 11/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6715 - accuracy: 0.5868
# Epoch 11: val_loss did not improve from 0.60073
# 799/799 [==============================] - 662s 828ms/step - loss: 0.6715 - accuracy: 0.5868 - val_loss: 0.6662 - val_accuracy: 0.5924
# Epoch 12/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6669 - accuracy: 0.5910
# Epoch 12: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 828ms/step - loss: 0.6669 - accuracy: 0.5910 - val_loss: 0.6630 - val_accuracy: 0.5952
# Epoch 13/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6635 - accuracy: 0.5950
# Epoch 13: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 828ms/step - loss: 0.6635 - accuracy: 0.5950 - val_loss: 0.6579 - val_accuracy: 0.6024
# Epoch 14/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6656 - accuracy: 0.5972
# Epoch 14: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 828ms/step - loss: 0.6656 - accuracy: 0.5972 - val_loss: 0.6620 - val_accuracy: 0.5969
# Epoch 15/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6608 - accuracy: 0.6035
# Epoch 15: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 827ms/step - loss: 0.6608 - accuracy: 0.6035 - val_loss: 0.6544 - val_accuracy: 0.6062
# Epoch 16/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6520 - accuracy: 0.6120
# Epoch 16: val_loss did not improve from 0.60073
# 799/799 [==============================] - 662s 828ms/step - loss: 0.6520 - accuracy: 0.6120 - val_loss: 0.6400 - val_accuracy: 0.6263
# Epoch 17/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6666 - accuracy: 0.6047
# Epoch 17: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 827ms/step - loss: 0.6666 - accuracy: 0.6047 - val_loss: 0.6592 - val_accuracy: 0.6003
# Epoch 18/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6577 - accuracy: 0.6041
# Epoch 18: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 827ms/step - loss: 0.6577 - accuracy: 0.6041 - val_loss: 0.6420 - val_accuracy: 0.6189
# Epoch 19/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6452 - accuracy: 0.6188
# Epoch 19: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 827ms/step - loss: 0.6452 - accuracy: 0.6188 - val_loss: 0.6314 - val_accuracy: 0.6316
# Epoch 20/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6658 - accuracy: 0.5957
# Epoch 20: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 827ms/step - loss: 0.6658 - accuracy: 0.5957 - val_loss: 0.6627 - val_accuracy: 0.5936
# Epoch 21/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6620 - accuracy: 0.5963
# Epoch 21: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 827ms/step - loss: 0.6620 - accuracy: 0.5963 - val_loss: 0.6505 - val_accuracy: 0.6075
# Epoch 22/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6512 - accuracy: 0.6085
# Epoch 22: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 827ms/step - loss: 0.6512 - accuracy: 0.6085 - val_loss: 0.6435 - val_accuracy: 0.6180
# Epoch 23/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6422 - accuracy: 0.6222
# Epoch 23: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 828ms/step - loss: 0.6422 - accuracy: 0.6222 - val_loss: 0.6279 - val_accuracy: 0.6420
# Epoch 24/500
# 799/799 [==============================] - ETA: 0s - loss: 9.1358 - accuracy: 0.5452
# Epoch 24: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 828ms/step - loss: 9.1358 - accuracy: 0.5452 - val_loss: 0.7612 - val_accuracy: 0.5240
# Epoch 25/500
# 799/799 [==============================] - ETA: 0s - loss: 1.7250 - accuracy: 0.5163
# Epoch 25: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 828ms/step - loss: 1.7250 - accuracy: 0.5163 - val_loss: 15.4984 - val_accuracy: 0.5009
# Epoch 26/500
# 799/799 [==============================] - ETA: 0s - loss: 2.4810 - accuracy: 0.5142
# Epoch 26: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 828ms/step - loss: 2.4810 - accuracy: 0.5142 - val_loss: 0.7570 - val_accuracy: 0.5456
# Epoch 27/500
# 799/799 [==============================] - ETA: 0s - loss: 1.4893 - accuracy: 0.5345
# Epoch 27: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 828ms/step - loss: 1.4893 - accuracy: 0.5345 - val_loss: 0.6893 - val_accuracy: 0.5590
# Epoch 28/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6966 - accuracy: 0.5515
# Epoch 28: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 827ms/step - loss: 0.6966 - accuracy: 0.5515 - val_loss: 0.6874 - val_accuracy: 0.5626
# Epoch 29/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6946 - accuracy: 0.5496
# Epoch 29: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 827ms/step - loss: 0.6946 - accuracy: 0.5496 - val_loss: 0.6860 - val_accuracy: 0.5615
# Epoch 30/500
# 799/799 [==============================] - ETA: 0s - loss: 7.9870 - accuracy: 0.5242
# Epoch 30: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 827ms/step - loss: 7.9870 - accuracy: 0.5242 - val_loss: 2.7735 - val_accuracy: 0.5004
# Epoch 31/500
# 799/799 [==============================] - ETA: 0s - loss: 1.6047 - accuracy: 0.5360
# Epoch 31: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 827ms/step - loss: 1.6047 - accuracy: 0.5360 - val_loss: 0.7160 - val_accuracy: 0.5582
# Epoch 32/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7110 - accuracy: 0.5467
# Epoch 32: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 827ms/step - loss: 0.7110 - accuracy: 0.5467 - val_loss: 0.7156 - val_accuracy: 0.5013
# Epoch 33/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7137 - accuracy: 0.5427
# Epoch 33: val_loss did not improve from 0.60073
# 799/799 [==============================] - 661s 827ms/step - loss: 0.7137 - accuracy: 0.5427 - val_loss: 0.6894 - val_accuracy: 0.5620
# Training Time:  21823.719032287598 seconds

# %% [markdown]
# # Saving the model and training history

# %%
lstm_model.save('LSTM_Architecture_16_Features.h5')
np.save('LSTM_history_16_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of LSTM Neural Network - 16 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of LSTM Neural Network - 16 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for LSTM Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[ -0.54725173],
#         [ -6.70051216],
#         [ -3.53210347],
#         ...,
#         [  4.47894551],
#         [  9.91199771],
#         [  5.04194149]],
#
#        [[ 15.10660785],
#         [ 12.89015194],
#         [  9.38198263],
#         ...,
#         [ -4.78630549],
#         [ -0.21452036],
#         [ -0.33307974]],
#
#        [[  2.93699623],
#         [  0.48231236],
#         [  3.60238997],
#         ...,
#         [  3.56256024],
#         [  4.05284678],
#         [  4.83590054]],
#
#        ...,
#
#        [[ -2.06647329],
#         [ -7.3330383 ],
#         [ -3.58371377],
#         ...,
#         [ -2.98855859],
#         [  0.65270226],
#         [ -5.03180252]],
#
#        [[ 22.22658066],
#         [ 25.39460655],
#         [ 14.46520722],
#         ...,
#         [ 17.16481672],
#         [ 13.51679866],
#         [ 17.76942708]],
#
#        [[-11.09871642],
#         [ -3.76626649],
#         [ -0.32644541],
#         ...,
#         [ -2.76463917],
#         [-12.88321662],
#         [ -5.83475996]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = lstm_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 138s 28ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = lstm_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.67, Test loss: 0.60

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.68      0.67     77586
#            1       0.67      0.66      0.67     77704
#
#     accuracy                           0.67    155290
#    macro avg       0.67      0.67      0.67    155290
# weighted avg       0.67      0.67      0.67    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix LSTM - 16 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.6695730568613562
# Precision: 0.6720873216661015
# Recall: 0.6632477092556368
# F1-score: 0.6676382573549415
# AUC-ROC: 0.7366418428200838

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['LSTM - 16'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()

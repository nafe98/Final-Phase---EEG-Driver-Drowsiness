# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 16/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 16/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 16/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 16/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - GRU</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from tensorflow.keras.layers import GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for GRU

# %%
X_train_array = X_train  
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (16, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001

# %% [markdown]
# # 2. Define Architecture

# %%
gru_model = Sequential([
    
    GRU(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1),
    GRU(256, activation='relu'),
    Dropout(0.1),
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
gru_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 16, 512)           791040
#
#  dropout (Dropout)           (None, 16, 512)           0
#
#  gru_1 (GRU)                 (None, 256)               591360
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,382,657
# Trainable params: 1,382,657
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
gru_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Integrating Callbacks</h2>
#
# </div>

# %% [markdown]
# ## EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# ## Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/GRU_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = gru_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping], 
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6435 - accuracy: 0.6230
# Epoch 1: val_loss improved from inf to 0.63494, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 702s 875ms/step - loss: 0.6435 - accuracy: 0.6230 - val_loss: 0.6349 - val_accuracy: 0.6352
# Epoch 2/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6127 - accuracy: 0.6565
# Epoch 2: val_loss improved from 0.63494 to 0.59712, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 697s 872ms/step - loss: 0.6127 - accuracy: 0.6565 - val_loss: 0.5971 - val_accuracy: 0.6700
# Epoch 3/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5864 - accuracy: 0.6818
# Epoch 3: val_loss improved from 0.59712 to 0.58381, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 697s 872ms/step - loss: 0.5864 - accuracy: 0.6818 - val_loss: 0.5838 - val_accuracy: 0.6817
# Epoch 4/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5738 - accuracy: 0.6914
# Epoch 4: val_loss improved from 0.58381 to 0.57211, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 697s 872ms/step - loss: 0.5738 - accuracy: 0.6914 - val_loss: 0.5721 - val_accuracy: 0.6921
# Epoch 5/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5644 - accuracy: 0.6993
# Epoch 5: val_loss improved from 0.57211 to 0.56553, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 697s 872ms/step - loss: 0.5644 - accuracy: 0.6993 - val_loss: 0.5655 - val_accuracy: 0.6977
# Epoch 6/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5580 - accuracy: 0.7044
# Epoch 6: val_loss improved from 0.56553 to 0.55999, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 697s 872ms/step - loss: 0.5580 - accuracy: 0.7044 - val_loss: 0.5600 - val_accuracy: 0.7031
# Epoch 7/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5955 - accuracy: 0.6744
# Epoch 7: val_loss did not improve from 0.55999
# 799/799 [==============================] - 696s 871ms/step - loss: 0.5955 - accuracy: 0.6744 - val_loss: 0.6011 - val_accuracy: 0.6688
# Epoch 8/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5957 - accuracy: 0.6773
# Epoch 8: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 872ms/step - loss: 0.5957 - accuracy: 0.6773 - val_loss: 0.6199 - val_accuracy: 0.6549
# Epoch 9/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5894 - accuracy: 0.6810
# Epoch 9: val_loss did not improve from 0.55999
# 799/799 [==============================] - 696s 872ms/step - loss: 0.5894 - accuracy: 0.6810 - val_loss: 0.6078 - val_accuracy: 0.6597
# Epoch 10/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6209 - accuracy: 0.6559
# Epoch 10: val_loss did not improve from 0.55999
# 799/799 [==============================] - 696s 872ms/step - loss: 0.6209 - accuracy: 0.6559 - val_loss: 0.6184 - val_accuracy: 0.6536
# Epoch 11/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6109 - accuracy: 0.6626
# Epoch 11: val_loss did not improve from 0.55999
# 799/799 [==============================] - 696s 872ms/step - loss: 0.6109 - accuracy: 0.6626 - val_loss: 0.5975 - val_accuracy: 0.6716
# Epoch 12/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6118 - accuracy: 0.6616
# Epoch 12: val_loss did not improve from 0.55999
# 799/799 [==============================] - 696s 871ms/step - loss: 0.6118 - accuracy: 0.6616 - val_loss: 0.5977 - val_accuracy: 0.6713
# Epoch 13/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5898 - accuracy: 0.6814
# Epoch 13: val_loss did not improve from 0.55999
# 799/799 [==============================] - 696s 871ms/step - loss: 0.5898 - accuracy: 0.6814 - val_loss: 0.5841 - val_accuracy: 0.6852
# Epoch 14/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5764 - accuracy: 0.6923
# Epoch 14: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 872ms/step - loss: 0.5764 - accuracy: 0.6923 - val_loss: 0.5745 - val_accuracy: 0.6922
# Epoch 15/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5777 - accuracy: 0.6922
# Epoch 15: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 872ms/step - loss: 0.5777 - accuracy: 0.6922 - val_loss: 0.6208 - val_accuracy: 0.6624
# Epoch 16/500
# 799/799 [==============================] - ETA: 0s - loss: 1.5223 - accuracy: 0.5721
# Epoch 16: val_loss did not improve from 0.55999
# 799/799 [==============================] - 696s 872ms/step - loss: 1.5223 - accuracy: 0.5721 - val_loss: 0.6731 - val_accuracy: 0.5846
# Epoch 17/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6729 - accuracy: 0.5827
# Epoch 17: val_loss did not improve from 0.55999
# 799/799 [==============================] - 696s 871ms/step - loss: 0.6729 - accuracy: 0.5827 - val_loss: 0.6708 - val_accuracy: 0.5872
# Epoch 18/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6721 - accuracy: 0.5843
# Epoch 18: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 872ms/step - loss: 0.6721 - accuracy: 0.5843 - val_loss: 0.6701 - val_accuracy: 0.5864
# Epoch 19/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6711 - accuracy: 0.5854
# Epoch 19: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 873ms/step - loss: 0.6711 - accuracy: 0.5854 - val_loss: 0.6687 - val_accuracy: 0.5893
# Epoch 20/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6704 - accuracy: 0.5863
# Epoch 20: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 872ms/step - loss: 0.6704 - accuracy: 0.5863 - val_loss: 0.6683 - val_accuracy: 0.5892
# Epoch 21/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6701 - accuracy: 0.5884
# Epoch 21: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 872ms/step - loss: 0.6701 - accuracy: 0.5884 - val_loss: 0.6663 - val_accuracy: 0.5925
# Epoch 22/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6682 - accuracy: 0.5896
# Epoch 22: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 872ms/step - loss: 0.6682 - accuracy: 0.5896 - val_loss: 0.6653 - val_accuracy: 0.5940
# Epoch 23/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6668 - accuracy: 0.5913
# Epoch 23: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 872ms/step - loss: 0.6668 - accuracy: 0.5913 - val_loss: 0.6639 - val_accuracy: 0.5950
# Epoch 24/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6662 - accuracy: 0.5913
# Epoch 24: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 872ms/step - loss: 0.6662 - accuracy: 0.5913 - val_loss: 0.6627 - val_accuracy: 0.5963
# Epoch 25/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6667 - accuracy: 0.5913
# Epoch 25: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 872ms/step - loss: 0.6667 - accuracy: 0.5913 - val_loss: 0.6635 - val_accuracy: 0.5960
# Epoch 26/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6655 - accuracy: 0.5935
# Epoch 26: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 873ms/step - loss: 0.6655 - accuracy: 0.5935 - val_loss: 0.6627 - val_accuracy: 0.5967
# Epoch 27/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6631 - accuracy: 0.5953
# Epoch 27: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 872ms/step - loss: 0.6631 - accuracy: 0.5953 - val_loss: 0.6584 - val_accuracy: 0.6006
# Epoch 28/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6633 - accuracy: 0.5973
# Epoch 28: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 872ms/step - loss: 0.6633 - accuracy: 0.5973 - val_loss: 0.6561 - val_accuracy: 0.6038
# Epoch 29/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6602 - accuracy: 0.5993
# Epoch 29: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 872ms/step - loss: 0.6602 - accuracy: 0.5993 - val_loss: 0.6558 - val_accuracy: 0.6047
# Epoch 30/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6590 - accuracy: 0.6009
# Epoch 30: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 872ms/step - loss: 0.6590 - accuracy: 0.6009 - val_loss: 0.6546 - val_accuracy: 0.6047
# Epoch 31/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6588 - accuracy: 0.6012
# Epoch 31: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 872ms/step - loss: 0.6588 - accuracy: 0.6012 - val_loss: 0.6547 - val_accuracy: 0.6035
# Epoch 32/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6573 - accuracy: 0.6027
# Epoch 32: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 872ms/step - loss: 0.6573 - accuracy: 0.6027 - val_loss: 0.6533 - val_accuracy: 0.6052
# Epoch 33/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6575 - accuracy: 0.6022
# Epoch 33: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 872ms/step - loss: 0.6575 - accuracy: 0.6022 - val_loss: 0.6577 - val_accuracy: 0.6028
# Epoch 34/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6590 - accuracy: 0.6013
# Epoch 34: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 873ms/step - loss: 0.6590 - accuracy: 0.6013 - val_loss: 0.6528 - val_accuracy: 0.6085
# Epoch 35/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6543 - accuracy: 0.6061
# Epoch 35: val_loss did not improve from 0.55999
# 799/799 [==============================] - 698s 873ms/step - loss: 0.6543 - accuracy: 0.6061 - val_loss: 0.6486 - val_accuracy: 0.6113
# Epoch 36/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6671 - accuracy: 0.5931
# Epoch 36: val_loss did not improve from 0.55999
# 799/799 [==============================] - 697s 873ms/step - loss: 0.6671 - accuracy: 0.5931 - val_loss: 0.6598 - val_accuracy: 0.6001
# Training Time:  25089.486298799515 seconds

# %% [markdown]
# # Saving the model and training history

# %%
gru_model.save('GRU_Architecture_16_Features.h5')
np.save('GRU_history_16_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of GRU Network - 16 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of GRU Network - 16 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for GRU Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[ -0.54725173],
#         [ -6.70051216],
#         [ -3.53210347],
#         ...,
#         [  4.47894551],
#         [  9.91199771],
#         [  5.04194149]],
#
#        [[ 15.10660785],
#         [ 12.89015194],
#         [  9.38198263],
#         ...,
#         [ -4.78630549],
#         [ -0.21452036],
#         [ -0.33307974]],
#
#        [[  2.93699623],
#         [  0.48231236],
#         [  3.60238997],
#         ...,
#         [  3.56256024],
#         [  4.05284678],
#         [  4.83590054]],
#
#        ...,
#
#        [[ -2.06647329],
#         [ -7.3330383 ],
#         [ -3.58371377],
#         ...,
#         [ -2.98855859],
#         [  0.65270226],
#         [ -5.03180252]],
#
#        [[ 22.22658066],
#         [ 25.39460655],
#         [ 14.46520722],
#         ...,
#         [ 17.16481672],
#         [ 13.51679866],
#         [ 17.76942708]],
#
#        [[-11.09871642],
#         [ -3.76626649],
#         [ -0.32644541],
#         ...,
#         [ -2.76463917],
#         [-12.88321662],
#         [ -5.83475996]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = gru_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 144s 30ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = gru_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.70, Test loss: 0.56

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.74      0.71     77586
#            1       0.72      0.67      0.69     77704
#
#     accuracy                           0.70    155290
#    macro avg       0.70      0.70      0.70    155290
# weighted avg       0.70      0.70      0.70    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix GRU - 16 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.7037542662116041
# Precision: 0.717803550816248
# Recall: 0.6722433851539175
# F1-score: 0.6942768281985167
# AUC-ROC: 0.7801288072387124

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['GRU - 16'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()

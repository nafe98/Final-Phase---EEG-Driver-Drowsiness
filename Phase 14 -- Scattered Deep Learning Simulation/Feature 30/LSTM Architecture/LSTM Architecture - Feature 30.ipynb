# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 30/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 30/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 30/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 30/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - LSTM</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
from keras.layers import LSTM
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for LSTM

# %%
X_train_array = X_train  
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (30, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001

# %% [markdown]
# # 2. Define Architecture

# %%
lstm_model = Sequential([
    
    LSTM(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1), 
    LSTM(256, activation='relu'),
    Dropout(0.1),  
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 512)           1052672
#
#  dropout (Dropout)           (None, 30, 512)           0
#
#  lstm_1 (LSTM)               (None, 256)               787456
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,840,385
# Trainable params: 1,840,385
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
lstm_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# ## Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/LSTM_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = lstm_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping],  
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - ETA: 0s - loss: 4.5273 - accuracy: 0.5956
# Epoch 1: val_loss improved from inf to 0.65636, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 1220s 2s/step - loss: 4.5273 - accuracy: 0.5956 - val_loss: 0.6564 - val_accuracy: 0.6186
# Epoch 2/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7046 - accuracy: 0.6164
# Epoch 2: val_loss did not improve from 0.65636
# 799/799 [==============================] - 1211s 2s/step - loss: 0.7046 - accuracy: 0.6164 - val_loss: 0.6572 - val_accuracy: 0.6175
# Epoch 3/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6476 - accuracy: 0.6277
# Epoch 3: val_loss improved from 0.65636 to 0.64244, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 1212s 2s/step - loss: 0.6476 - accuracy: 0.6277 - val_loss: 0.6424 - val_accuracy: 0.6295
# Epoch 4/500
# 799/799 [==============================] - ETA: 0s - loss: 0.8455 - accuracy: 0.5737
# Epoch 4: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 0.8455 - accuracy: 0.5737 - val_loss: 0.6773 - val_accuracy: 0.5694
# Epoch 5/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6760 - accuracy: 0.5785
# Epoch 5: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 0.6760 - accuracy: 0.5785 - val_loss: 0.6717 - val_accuracy: 0.5874
# Epoch 6/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6755 - accuracy: 0.5965
# Epoch 6: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1212s 2s/step - loss: 0.6755 - accuracy: 0.5965 - val_loss: 0.6735 - val_accuracy: 0.6002
# Epoch 7/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6587 - accuracy: 0.6157
# Epoch 7: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1212s 2s/step - loss: 0.6587 - accuracy: 0.6157 - val_loss: 0.6572 - val_accuracy: 0.6151
# Epoch 8/500
# 799/799 [==============================] - ETA: 0s - loss: 18866480.0000 - accuracy: 0.5827
# Epoch 8: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 18866480.0000 - accuracy: 0.5827 - val_loss: 110.2333 - val_accuracy: 0.5000
# Epoch 9/500
# 799/799 [==============================] - ETA: 0s - loss: 7606.7964 - accuracy: 0.4989
# Epoch 9: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 7606.7964 - accuracy: 0.4989 - val_loss: 48.4867 - val_accuracy: 0.4858
# Epoch 10/500
# 799/799 [==============================] - ETA: 0s - loss: 278.9960 - accuracy: 0.5079
# Epoch 10: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 278.9960 - accuracy: 0.5079 - val_loss: 64.4098 - val_accuracy: 0.5097
# Epoch 11/500
# 799/799 [==============================] - ETA: 0s - loss: 46.1979 - accuracy: 0.5202
# Epoch 11: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 46.1979 - accuracy: 0.5202 - val_loss: 2.5581 - val_accuracy: 0.5338
# Epoch 12/500
# 799/799 [==============================] - ETA: 0s - loss: 22.8405 - accuracy: 0.5193
# Epoch 12: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1212s 2s/step - loss: 22.8405 - accuracy: 0.5193 - val_loss: 51.1735 - val_accuracy: 0.5002
# Epoch 13/500
# 799/799 [==============================] - ETA: 0s - loss: 20.1379 - accuracy: 0.5187
# Epoch 13: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 20.1379 - accuracy: 0.5187 - val_loss: 12.0572 - val_accuracy: 0.5044
# Epoch 14/500
# 799/799 [==============================] - ETA: 0s - loss: 19.0320 - accuracy: 0.5224
# Epoch 14: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 19.0320 - accuracy: 0.5224 - val_loss: 37.4737 - val_accuracy: 0.5206
# Epoch 15/500
# 799/799 [==============================] - ETA: 0s - loss: 18.2758 - accuracy: 0.5242
# Epoch 15: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1212s 2s/step - loss: 18.2758 - accuracy: 0.5242 - val_loss: 21.9185 - val_accuracy: 0.5436
# Epoch 16/500
# 799/799 [==============================] - ETA: 0s - loss: 13.0754 - accuracy: 0.5301
# Epoch 16: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 13.0754 - accuracy: 0.5301 - val_loss: 57.3885 - val_accuracy: 0.5091
# Epoch 17/500
# 799/799 [==============================] - ETA: 0s - loss: 12.6827 - accuracy: 0.5308
# Epoch 17: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1210s 2s/step - loss: 12.6827 - accuracy: 0.5308 - val_loss: 25.2842 - val_accuracy: 0.5401
# Epoch 18/500
# 799/799 [==============================] - ETA: 0s - loss: 47.6994 - accuracy: 0.5227
# Epoch 18: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 47.6994 - accuracy: 0.5227 - val_loss: 2.5190 - val_accuracy: 0.5212
# Epoch 19/500
# 799/799 [==============================] - ETA: 0s - loss: 4.7168 - accuracy: 0.5265
# Epoch 19: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 4.7168 - accuracy: 0.5265 - val_loss: 2.3618 - val_accuracy: 0.5305
# Epoch 20/500
# 799/799 [==============================] - ETA: 0s - loss: 1.0365 - accuracy: 0.5449
# Epoch 20: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 1.0365 - accuracy: 0.5449 - val_loss: 0.7757 - val_accuracy: 0.5438
# Epoch 21/500
# 799/799 [==============================] - ETA: 0s - loss: 0.8470 - accuracy: 0.5427
# Epoch 21: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 0.8470 - accuracy: 0.5427 - val_loss: 0.7236 - val_accuracy: 0.5340
# Epoch 22/500
# 799/799 [==============================] - ETA: 0s - loss: 0.8545 - accuracy: 0.5449
# Epoch 22: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 0.8545 - accuracy: 0.5449 - val_loss: 0.8909 - val_accuracy: 0.5052
# Epoch 23/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7314 - accuracy: 0.5531
# Epoch 23: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 0.7314 - accuracy: 0.5531 - val_loss: 0.6979 - val_accuracy: 0.5614
# Epoch 24/500
# 799/799 [==============================] - ETA: 0s - loss: 0.8115 - accuracy: 0.5530
# Epoch 24: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 0.8115 - accuracy: 0.5530 - val_loss: 1.0064 - val_accuracy: 0.5487
# Epoch 25/500
# 799/799 [==============================] - ETA: 0s - loss: 6.6815 - accuracy: 0.5357
# Epoch 25: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1210s 2s/step - loss: 6.6815 - accuracy: 0.5357 - val_loss: 0.7763 - val_accuracy: 0.5240
# Epoch 26/500
# 799/799 [==============================] - ETA: 0s - loss: 1.1710 - accuracy: 0.5382
# Epoch 26: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1210s 2s/step - loss: 1.1710 - accuracy: 0.5382 - val_loss: 0.7440 - val_accuracy: 0.5211
# Epoch 27/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7382 - accuracy: 0.5510
# Epoch 27: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1210s 2s/step - loss: 0.7382 - accuracy: 0.5510 - val_loss: 0.7000 - val_accuracy: 0.5435
# Epoch 28/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7182 - accuracy: 0.5536
# Epoch 28: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 0.7182 - accuracy: 0.5536 - val_loss: 0.7168 - val_accuracy: 0.5631
# Epoch 29/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7217 - accuracy: 0.5533
# Epoch 29: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1210s 2s/step - loss: 0.7217 - accuracy: 0.5533 - val_loss: 0.7177 - val_accuracy: 0.5153
# Epoch 30/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7248 - accuracy: 0.5520
# Epoch 30: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 0.7248 - accuracy: 0.5520 - val_loss: 0.6982 - val_accuracy: 0.5699
# Epoch 31/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7175 - accuracy: 0.5551
# Epoch 31: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 0.7175 - accuracy: 0.5551 - val_loss: 0.8034 - val_accuracy: 0.5580
# Epoch 32/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7194 - accuracy: 0.5550
# Epoch 32: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1211s 2s/step - loss: 0.7194 - accuracy: 0.5550 - val_loss: 0.7253 - val_accuracy: 0.5618
# Epoch 33/500
# 799/799 [==============================] - ETA: 0s - loss: 1.9746 - accuracy: 0.5401
# Epoch 33: val_loss did not improve from 0.64244
# 799/799 [==============================] - 1210s 2s/step - loss: 1.9746 - accuracy: 0.5401 - val_loss: 0.9800 - val_accuracy: 0.5055
# Training Time:  39973.31214976311 seconds

# %% [markdown]
# # Saving the model and training history

# %%
lstm_model.save('LSTM_Architecture_30_Features.h5')
np.save('LSTM_history_30_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of LSTM Neural Network - 30 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of LSTM Neural Network - 30 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for LSTM Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[ -0.54725173],
#         [ -6.70051216],
#         [ -3.53210347],
#         ...,
#         [  2.38606711],
#         [ -0.7897333 ],
#         [ -1.53368896]],
#
#        [[ 15.10660785],
#         [ 12.89015194],
#         [  9.38198263],
#         ...,
#         [  4.61856463],
#         [  0.41360934],
#         [ 11.24395231]],
#
#        [[  2.93699623],
#         [  0.48231236],
#         [  3.60238997],
#         ...,
#         [  0.54190183],
#         [  4.71643263],
#         [ -2.47770204]],
#
#        ...,
#
#        [[ -2.06647329],
#         [ -7.3330383 ],
#         [ -3.58371377],
#         ...,
#         [  0.53832682],
#         [ -8.4925254 ],
#         [ -2.61201433]],
#
#        [[ 22.22658066],
#         [ 25.39460655],
#         [ 14.46520722],
#         ...,
#         [ 36.26377457],
#         [ 20.76411391],
#         [ 34.25462728]],
#
#        [[-11.09871642],
#         [ -3.76626649],
#         [ -0.32644541],
#         ...,
#         [-17.53730582],
#         [-10.74285156],
#         [ -9.85255786]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = lstm_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 246s 51ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = lstm_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.63, Test loss: 0.64

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.70      0.66     77586
#            1       0.65      0.57      0.61     77704
#
#     accuracy                           0.63    155290
#    macro avg       0.64      0.63      0.63    155290
# weighted avg       0.64      0.63      0.63    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix LSTM - 30 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.6342327258677314
# Precision: 0.653855212412047
# Recall: 0.5716436734273654
# F1-score: 0.6099918977190019
# AUC-ROC: 0.6824170208751911

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['LSTM - 30'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()

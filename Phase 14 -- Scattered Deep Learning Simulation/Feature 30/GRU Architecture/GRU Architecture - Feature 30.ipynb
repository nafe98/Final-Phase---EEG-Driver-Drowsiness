# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 30/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 30/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 30/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 30/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - GRU</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from tensorflow.keras.layers import GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for GRU

# %%
X_train_array = X_train  
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (30, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001

# %% [markdown]
# # 2. Define Architecture

# %%
gru_model = Sequential([
    
    GRU(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1),
    GRU(256, activation='relu'),
    Dropout(0.1),
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
gru_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 30, 512)           791040
#
#  dropout (Dropout)           (None, 30, 512)           0
#
#  gru_1 (GRU)                 (None, 256)               591360
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,382,657
# Trainable params: 1,382,657
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
gru_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Integrating Callbacks</h2>
#
# </div>

# %% [markdown]
# ## EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# ## Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/GRU_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = gru_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping], 
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6487 - accuracy: 0.6218
# Epoch 1: val_loss improved from inf to 0.63288, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 1292s 2s/step - loss: 0.6487 - accuracy: 0.6218 - val_loss: 0.6329 - val_accuracy: 0.6359
# Epoch 2/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6175 - accuracy: 0.6539
# Epoch 2: val_loss improved from 0.63288 to 0.60593, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6175 - accuracy: 0.6539 - val_loss: 0.6059 - val_accuracy: 0.6638
# Epoch 3/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6363 - accuracy: 0.6375
# Epoch 3: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1286s 2s/step - loss: 0.6363 - accuracy: 0.6375 - val_loss: 0.6456 - val_accuracy: 0.6272
# Epoch 4/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6345 - accuracy: 0.6402
# Epoch 4: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1284s 2s/step - loss: 0.6345 - accuracy: 0.6402 - val_loss: 0.6312 - val_accuracy: 0.6429
# Epoch 5/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6323 - accuracy: 0.6422
# Epoch 5: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6323 - accuracy: 0.6422 - val_loss: 0.6696 - val_accuracy: 0.5868
# Epoch 6/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6600 - accuracy: 0.6041
# Epoch 6: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6600 - accuracy: 0.6041 - val_loss: 0.6492 - val_accuracy: 0.6193
# Epoch 7/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6460 - accuracy: 0.6243
# Epoch 7: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1284s 2s/step - loss: 0.6460 - accuracy: 0.6243 - val_loss: 0.6388 - val_accuracy: 0.6270
# Epoch 8/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6286 - accuracy: 0.6429
# Epoch 8: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1284s 2s/step - loss: 0.6286 - accuracy: 0.6429 - val_loss: 0.6155 - val_accuracy: 0.6532
# Epoch 9/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6406 - accuracy: 0.6285
# Epoch 9: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6406 - accuracy: 0.6285 - val_loss: 0.6398 - val_accuracy: 0.6264
# Epoch 10/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6573 - accuracy: 0.6043
# Epoch 10: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1284s 2s/step - loss: 0.6573 - accuracy: 0.6043 - val_loss: 0.6671 - val_accuracy: 0.5913
# Epoch 11/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6653 - accuracy: 0.5936
# Epoch 11: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6653 - accuracy: 0.5936 - val_loss: 0.6549 - val_accuracy: 0.6043
# Epoch 12/500
# 799/799 [==============================] - ETA: 0s - loss: 4.4045 - accuracy: 0.5731
# Epoch 12: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1284s 2s/step - loss: 4.4045 - accuracy: 0.5731 - val_loss: 0.6778 - val_accuracy: 0.5730
# Epoch 13/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6786 - accuracy: 0.5775
# Epoch 13: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1284s 2s/step - loss: 0.6786 - accuracy: 0.5775 - val_loss: 0.6756 - val_accuracy: 0.5780
# Epoch 14/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6751 - accuracy: 0.5808
# Epoch 14: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6751 - accuracy: 0.5808 - val_loss: 0.6735 - val_accuracy: 0.5829
# Epoch 15/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6735 - accuracy: 0.5846
# Epoch 15: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1284s 2s/step - loss: 0.6735 - accuracy: 0.5846 - val_loss: 0.6689 - val_accuracy: 0.5886
# Epoch 16/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6689 - accuracy: 0.5897
# Epoch 16: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6689 - accuracy: 0.5897 - val_loss: 0.6666 - val_accuracy: 0.5955
# Epoch 17/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6673 - accuracy: 0.5932
# Epoch 17: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1284s 2s/step - loss: 0.6673 - accuracy: 0.5932 - val_loss: 0.6652 - val_accuracy: 0.5965
# Epoch 18/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6634 - accuracy: 0.5975
# Epoch 18: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6634 - accuracy: 0.5975 - val_loss: 0.6580 - val_accuracy: 0.6081
# Epoch 19/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6577 - accuracy: 0.6083
# Epoch 19: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1284s 2s/step - loss: 0.6577 - accuracy: 0.6083 - val_loss: 0.6499 - val_accuracy: 0.6228
# Epoch 20/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6514 - accuracy: 0.6186
# Epoch 20: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6514 - accuracy: 0.6186 - val_loss: 0.6479 - val_accuracy: 0.6247
# Epoch 21/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6510 - accuracy: 0.6208
# Epoch 21: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6510 - accuracy: 0.6208 - val_loss: 0.6412 - val_accuracy: 0.6316
# Epoch 22/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6381 - accuracy: 0.6356
# Epoch 22: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6381 - accuracy: 0.6356 - val_loss: 0.6278 - val_accuracy: 0.6447
# Epoch 23/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6292 - accuracy: 0.6441
# Epoch 23: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6292 - accuracy: 0.6441 - val_loss: 0.6201 - val_accuracy: 0.6506
# Epoch 24/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6380 - accuracy: 0.6356
# Epoch 24: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6380 - accuracy: 0.6356 - val_loss: 0.6426 - val_accuracy: 0.6310
# Epoch 25/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6415 - accuracy: 0.6292
# Epoch 25: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6415 - accuracy: 0.6292 - val_loss: 0.6493 - val_accuracy: 0.6160
# Epoch 26/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6414 - accuracy: 0.6254
# Epoch 26: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6414 - accuracy: 0.6254 - val_loss: 0.6359 - val_accuracy: 0.6327
# Epoch 27/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6340 - accuracy: 0.6349
# Epoch 27: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6340 - accuracy: 0.6349 - val_loss: 0.6249 - val_accuracy: 0.6468
# Epoch 28/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6269 - accuracy: 0.6450
# Epoch 28: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1285s 2s/step - loss: 0.6269 - accuracy: 0.6450 - val_loss: 0.6218 - val_accuracy: 0.6493
# Epoch 29/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6442 - accuracy: 0.6464
# Epoch 29: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1284s 2s/step - loss: 0.6442 - accuracy: 0.6464 - val_loss: 0.6154 - val_accuracy: 0.6559
# Epoch 30/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6546 - accuracy: 0.6139
# Epoch 30: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1283s 2s/step - loss: 0.6546 - accuracy: 0.6139 - val_loss: 0.6419 - val_accuracy: 0.6245
# Epoch 31/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6476 - accuracy: 0.6166
# Epoch 31: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1284s 2s/step - loss: 0.6476 - accuracy: 0.6166 - val_loss: 0.6638 - val_accuracy: 0.5935
# Epoch 32/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6647 - accuracy: 0.5921
# Epoch 32: val_loss did not improve from 0.60593
# 799/799 [==============================] - 1284s 2s/step - loss: 0.6647 - accuracy: 0.5921 - val_loss: 0.6589 - val_accuracy: 0.5993
# Training Time:  41116.612443208694 seconds

# %% [markdown]
# # Saving the model and training history

# %%
gru_model.save('GRU_Architecture_30_Features.h5')
np.save('GRU_history_30_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of GRU Network - 30 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of GRU Network - 30 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for GRU Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[ -0.54725173],
#         [ -6.70051216],
#         [ -3.53210347],
#         ...,
#         [  2.38606711],
#         [ -0.7897333 ],
#         [ -1.53368896]],
#
#        [[ 15.10660785],
#         [ 12.89015194],
#         [  9.38198263],
#         ...,
#         [  4.61856463],
#         [  0.41360934],
#         [ 11.24395231]],
#
#        [[  2.93699623],
#         [  0.48231236],
#         [  3.60238997],
#         ...,
#         [  0.54190183],
#         [  4.71643263],
#         [ -2.47770204]],
#
#        ...,
#
#        [[ -2.06647329],
#         [ -7.3330383 ],
#         [ -3.58371377],
#         ...,
#         [  0.53832682],
#         [ -8.4925254 ],
#         [ -2.61201433]],
#
#        [[ 22.22658066],
#         [ 25.39460655],
#         [ 14.46520722],
#         ...,
#         [ 36.26377457],
#         [ 20.76411391],
#         [ 34.25462728]],
#
#        [[-11.09871642],
#         [ -3.76626649],
#         [ -0.32644541],
#         ...,
#         [-17.53730582],
#         [-10.74285156],
#         [ -9.85255786]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = gru_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 252s 52ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = gru_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.67, Test loss: 0.60

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.78      0.70     77586
#            1       0.72      0.55      0.62     77704
#
#     accuracy                           0.67    155290
#    macro avg       0.68      0.67      0.66    155290
# weighted avg       0.68      0.67      0.66    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix GRU - 30 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.6662438019189902
# Precision: 0.7182844319964906
# Recall: 0.547873983321322
# F1-score: 0.6216115584823286
# AUC-ROC: 0.7321035167429104

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['GRU - 30'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()

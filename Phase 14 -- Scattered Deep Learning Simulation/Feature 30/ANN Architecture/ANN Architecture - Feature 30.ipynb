# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 30/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 30/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 30/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 30/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - ANN</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# # 1. Network Initialization

# %%
input_dim = X_train.shape[1]  

batch_size = 1024 
epochs = 500  
learning_rate = 0.0001  
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# # 2. Define Architecture

# %%
ann_model = Sequential([
    
    Dense(2048, input_dim=input_dim, activation='relu'),
    Dense(1024, activation='relu'),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid') 
    
])

# %%
ann_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2048)              63488
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dense_6 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,859,009
# Trainable params: 2,859,009
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
ann_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# # Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/ANN_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = ann_model.fit(X_train, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping],  
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6038 - accuracy: 0.6668
# Epoch 1: val_loss improved from inf to 0.57630, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 36s 65ms/step - loss: 0.6038 - accuracy: 0.6668 - val_loss: 0.5763 - val_accuracy: 0.6958
# Epoch 2/500
# 546/546 [==============================] - ETA: 0s - loss: 0.5606 - accuracy: 0.7094
# Epoch 2: val_loss improved from 0.57630 to 0.55197, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.5606 - accuracy: 0.7094 - val_loss: 0.5520 - val_accuracy: 0.7144
# Epoch 3/500
# 546/546 [==============================] - ETA: 0s - loss: 0.5365 - accuracy: 0.7266
# Epoch 3: val_loss improved from 0.55197 to 0.53367, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.5365 - accuracy: 0.7266 - val_loss: 0.5337 - val_accuracy: 0.7279
# Epoch 4/500
# 546/546 [==============================] - ETA: 0s - loss: 0.5176 - accuracy: 0.7395
# Epoch 4: val_loss improved from 0.53367 to 0.51955, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.5176 - accuracy: 0.7395 - val_loss: 0.5196 - val_accuracy: 0.7373
# Epoch 5/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4986 - accuracy: 0.7525
# Epoch 5: val_loss improved from 0.51955 to 0.50667, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.4986 - accuracy: 0.7525 - val_loss: 0.5067 - val_accuracy: 0.7460
# Epoch 6/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.4811 - accuracy: 0.7635
# Epoch 6: val_loss improved from 0.50667 to 0.49552, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.4811 - accuracy: 0.7635 - val_loss: 0.4955 - val_accuracy: 0.7528
# Epoch 7/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4639 - accuracy: 0.7753
# Epoch 7: val_loss improved from 0.49552 to 0.48600, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 62ms/step - loss: 0.4639 - accuracy: 0.7753 - val_loss: 0.4860 - val_accuracy: 0.7601
# Epoch 8/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4481 - accuracy: 0.7849
# Epoch 8: val_loss improved from 0.48600 to 0.48535, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.4481 - accuracy: 0.7849 - val_loss: 0.4854 - val_accuracy: 0.7614
# Epoch 9/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4316 - accuracy: 0.7947
# Epoch 9: val_loss improved from 0.48535 to 0.47309, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.4316 - accuracy: 0.7947 - val_loss: 0.4731 - val_accuracy: 0.7672
# Epoch 10/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.4161 - accuracy: 0.8043
# Epoch 10: val_loss did not improve from 0.47309
# 546/546 [==============================] - 34s 62ms/step - loss: 0.4160 - accuracy: 0.8043 - val_loss: 0.4772 - val_accuracy: 0.7720
# Epoch 11/500
# 546/546 [==============================] - ETA: 0s - loss: 0.4001 - accuracy: 0.8135
# Epoch 11: val_loss improved from 0.47309 to 0.46477, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 62ms/step - loss: 0.4001 - accuracy: 0.8135 - val_loss: 0.4648 - val_accuracy: 0.7749
# Epoch 12/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3845 - accuracy: 0.8224
# Epoch 12: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3845 - accuracy: 0.8224 - val_loss: 0.4655 - val_accuracy: 0.7775
# Epoch 13/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3684 - accuracy: 0.8316
# Epoch 13: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3684 - accuracy: 0.8316 - val_loss: 0.4686 - val_accuracy: 0.7786
# Epoch 14/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3537 - accuracy: 0.8400
# Epoch 14: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3537 - accuracy: 0.8400 - val_loss: 0.4675 - val_accuracy: 0.7814
# Epoch 15/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3386 - accuracy: 0.8484
# Epoch 15: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3386 - accuracy: 0.8484 - val_loss: 0.4722 - val_accuracy: 0.7786
# Epoch 16/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3224 - accuracy: 0.8565
# Epoch 16: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3224 - accuracy: 0.8565 - val_loss: 0.4719 - val_accuracy: 0.7844
# Epoch 17/500
# 546/546 [==============================] - ETA: 0s - loss: 0.3074 - accuracy: 0.8647
# Epoch 17: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.3074 - accuracy: 0.8647 - val_loss: 0.4864 - val_accuracy: 0.7851
# Epoch 18/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.2937 - accuracy: 0.8715
# Epoch 18: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2937 - accuracy: 0.8715 - val_loss: 0.4912 - val_accuracy: 0.7842
# Epoch 19/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2771 - accuracy: 0.8801
# Epoch 19: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2771 - accuracy: 0.8801 - val_loss: 0.5077 - val_accuracy: 0.7830
# Epoch 20/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.2633 - accuracy: 0.8872
# Epoch 20: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2633 - accuracy: 0.8871 - val_loss: 0.5034 - val_accuracy: 0.7875
# Epoch 21/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2480 - accuracy: 0.8942
# Epoch 21: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2480 - accuracy: 0.8942 - val_loss: 0.5201 - val_accuracy: 0.7844
# Epoch 22/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2344 - accuracy: 0.9008
# Epoch 22: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2344 - accuracy: 0.9008 - val_loss: 0.5336 - val_accuracy: 0.7864
# Epoch 23/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.2198 - accuracy: 0.9079
# Epoch 23: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2198 - accuracy: 0.9078 - val_loss: 0.5519 - val_accuracy: 0.7829
# Epoch 24/500
# 546/546 [==============================] - ETA: 0s - loss: 0.2067 - accuracy: 0.9141
# Epoch 24: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.2067 - accuracy: 0.9141 - val_loss: 0.5663 - val_accuracy: 0.7864
# Epoch 25/500
# 546/546 [==============================] - ETA: 0s - loss: 0.1924 - accuracy: 0.9203
# Epoch 25: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.1924 - accuracy: 0.9203 - val_loss: 0.5942 - val_accuracy: 0.7825
# Epoch 26/500
# 546/546 [==============================] - ETA: 0s - loss: 0.1825 - accuracy: 0.9253
# Epoch 26: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.1825 - accuracy: 0.9253 - val_loss: 0.6080 - val_accuracy: 0.7871
# Epoch 27/500
# 546/546 [==============================] - ETA: 0s - loss: 0.1686 - accuracy: 0.9315
# Epoch 27: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.1686 - accuracy: 0.9315 - val_loss: 0.6500 - val_accuracy: 0.7845
# Epoch 28/500
# 546/546 [==============================] - ETA: 0s - loss: 0.1585 - accuracy: 0.9358
# Epoch 28: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.1585 - accuracy: 0.9358 - val_loss: 0.6719 - val_accuracy: 0.7833
# Epoch 29/500
# 546/546 [==============================] - ETA: 0s - loss: 0.1472 - accuracy: 0.9409
# Epoch 29: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.1472 - accuracy: 0.9409 - val_loss: 0.6834 - val_accuracy: 0.7833
# Epoch 30/500
# 546/546 [==============================] - ETA: 0s - loss: 0.1370 - accuracy: 0.9454
# Epoch 30: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.1370 - accuracy: 0.9454 - val_loss: 0.7151 - val_accuracy: 0.7840
# Epoch 31/500
# 546/546 [==============================] - ETA: 0s - loss: 0.1290 - accuracy: 0.9487
# Epoch 31: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.1290 - accuracy: 0.9487 - val_loss: 0.7272 - val_accuracy: 0.7861
# Epoch 32/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.1196 - accuracy: 0.9531
# Epoch 32: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.1196 - accuracy: 0.9530 - val_loss: 0.7740 - val_accuracy: 0.7819
# Epoch 33/500
# 546/546 [==============================] - ETA: 0s - loss: 0.1124 - accuracy: 0.9560
# Epoch 33: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.1124 - accuracy: 0.9560 - val_loss: 0.7830 - val_accuracy: 0.7798
# Epoch 34/500
# 546/546 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9588
# Epoch 34: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.1065 - accuracy: 0.9588 - val_loss: 0.8089 - val_accuracy: 0.7828
# Epoch 35/500
# 546/546 [==============================] - ETA: 0s - loss: 0.0967 - accuracy: 0.9623
# Epoch 35: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.0967 - accuracy: 0.9623 - val_loss: 0.8496 - val_accuracy: 0.7824
# Epoch 36/500
# 546/546 [==============================] - ETA: 0s - loss: 0.0921 - accuracy: 0.9645
# Epoch 36: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.0921 - accuracy: 0.9645 - val_loss: 0.8621 - val_accuracy: 0.7803
# Epoch 37/500
# 546/546 [==============================] - ETA: 0s - loss: 0.0906 - accuracy: 0.9651
# Epoch 37: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.0906 - accuracy: 0.9651 - val_loss: 0.8979 - val_accuracy: 0.7773
# Epoch 38/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.0819 - accuracy: 0.9687
# Epoch 38: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.0820 - accuracy: 0.9686 - val_loss: 0.9159 - val_accuracy: 0.7848
# Epoch 39/500
# 546/546 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9701
# Epoch 39: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.0779 - accuracy: 0.9701 - val_loss: 0.9545 - val_accuracy: 0.7828
# Epoch 40/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.0755 - accuracy: 0.9714
# Epoch 40: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.0755 - accuracy: 0.9714 - val_loss: 0.9527 - val_accuracy: 0.7827
# Epoch 41/500
# 546/546 [==============================] - ETA: 0s - loss: 0.0750 - accuracy: 0.9716
# Epoch 41: val_loss did not improve from 0.46477
# 546/546 [==============================] - 34s 62ms/step - loss: 0.0750 - accuracy: 0.9716 - val_loss: 0.9818 - val_accuracy: 0.7846
# Training Time:  1393.0450251102448 seconds
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2294 - accuracy: 0.8992 - val_loss: 0.3498 - val_accuracy: 0.8500
# Epoch 172/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2320 - accuracy: 0.8974 - val_loss: 0.3431 - val_accuracy: 0.8541
# Epoch 173/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2299 - accuracy: 0.8986 - val_loss: 0.3470 - val_accuracy: 0.8517
# Epoch 174/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2261 - accuracy: 0.9005 - val_loss: 0.3436 - val_accuracy: 0.8545
# Epoch 175/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2243 - accuracy: 0.9015 - val_loss: 0.3429 - val_accuracy: 0.8559
# Epoch 176/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2274 - accuracy: 0.9000 - val_loss: 0.3438 - val_accuracy: 0.8523
# Epoch 177/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2250 - accuracy: 0.9012 - val_loss: 0.3489 - val_accuracy: 0.8524
# Epoch 178/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2264 - accuracy: 0.9010 - val_loss: 0.3247 - val_accuracy: 0.8600
# Epoch 179/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2227 - accuracy: 0.9023 - val_loss: 0.3299 - val_accuracy: 0.8587
# Epoch 180/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2228 - accuracy: 0.9023 - val_loss: 0.3341 - val_accuracy: 0.8560
# Epoch 181/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2216 - accuracy: 0.9034 - val_loss: 0.3569 - val_accuracy: 0.8495
# Epoch 182/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2267 - accuracy: 0.9003 - val_loss: 0.3481 - val_accuracy: 0.8520
# Epoch 183/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2150 - accuracy: 0.9059 - val_loss: 0.3411 - val_accuracy: 0.8532
# Epoch 184/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2170 - accuracy: 0.9058 - val_loss: 0.3354 - val_accuracy: 0.8567
# Epoch 185/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2204 - accuracy: 0.9033 - val_loss: 0.3583 - val_accuracy: 0.8495
# Epoch 186/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2169 - accuracy: 0.9050 - val_loss: 0.3391 - val_accuracy: 0.8576
# Epoch 187/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2179 - accuracy: 0.9045 - val_loss: 0.3454 - val_accuracy: 0.8541
# Epoch 188/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2167 - accuracy: 0.9055 - val_loss: 0.3566 - val_accuracy: 0.8504
# Epoch 189/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2145 - accuracy: 0.9066 - val_loss: 0.3299 - val_accuracy: 0.8591
# Epoch 190/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2161 - accuracy: 0.9058 - val_loss: 0.3644 - val_accuracy: 0.8465
# Epoch 191/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2174 - accuracy: 0.9052 - val_loss: 0.3444 - val_accuracy: 0.8561
# Epoch 192/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2141 - accuracy: 0.9074 - val_loss: 0.3429 - val_accuracy: 0.8564
# Epoch 193/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2154 - accuracy: 0.9063 - val_loss: 0.4258 - val_accuracy: 0.8288
# Epoch 194/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2121 - accuracy: 0.9081 - val_loss: 0.3417 - val_accuracy: 0.8588
# Epoch 195/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2104 - accuracy: 0.9083 - val_loss: 0.3510 - val_accuracy: 0.8502
# Epoch 196/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2098 - accuracy: 0.9087 - val_loss: 0.3458 - val_accuracy: 0.8537
# Epoch 197/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2115 - accuracy: 0.9084 - val_loss: 0.3613 - val_accuracy: 0.8542
# Epoch 198/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2105 - accuracy: 0.9084 - val_loss: 0.3449 - val_accuracy: 0.8540
# Epoch 199/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2083 - accuracy: 0.9100 - val_loss: 0.3484 - val_accuracy: 0.8523
# Epoch 200/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2091 - accuracy: 0.9091 - val_loss: 0.3327 - val_accuracy: 0.8607
# Epoch 201/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2097 - accuracy: 0.9091 - val_loss: 0.3247 - val_accuracy: 0.8642
# Epoch 202/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2064 - accuracy: 0.9105 - val_loss: 0.3462 - val_accuracy: 0.8546
# Epoch 203/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2042 - accuracy: 0.9115 - val_loss: 0.3460 - val_accuracy: 0.8576
# Epoch 204/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2058 - accuracy: 0.9106 - val_loss: 0.3629 - val_accuracy: 0.8533
# Epoch 205/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2039 - accuracy: 0.9117 - val_loss: 0.3302 - val_accuracy: 0.8626
# Epoch 206/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2030 - accuracy: 0.9122 - val_loss: 0.3508 - val_accuracy: 0.8573
# Epoch 207/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2072 - accuracy: 0.9105 - val_loss: 0.3381 - val_accuracy: 0.8586
# Epoch 208/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2011 - accuracy: 0.9132 - val_loss: 0.3285 - val_accuracy: 0.8644
# Epoch 209/500
# 546/546 [==============================] - 2s 5ms/step - loss: 0.1990 - accuracy: 0.9140 - val_loss: 0.3392 - val_accuracy: 0.8584
# Epoch 210/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2018 - accuracy: 0.9128 - val_loss: 0.3411 - val_accuracy: 0.8610
# Epoch 211/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2014 - accuracy: 0.9135 - val_loss: 0.3310 - val_accuracy: 0.8619
# Epoch 212/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2015 - accuracy: 0.9133 - val_loss: 0.3612 - val_accuracy: 0.8469
# Epoch 213/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1966 - accuracy: 0.9153 - val_loss: 0.3378 - val_accuracy: 0.8650
# Epoch 214/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2009 - accuracy: 0.9131 - val_loss: 0.3392 - val_accuracy: 0.8652
# Epoch 215/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1976 - accuracy: 0.9146 - val_loss: 0.3993 - val_accuracy: 0.8365
# Epoch 216/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1954 - accuracy: 0.9159 - val_loss: 0.3228 - val_accuracy: 0.8677
# Epoch 217/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1963 - accuracy: 0.9153 - val_loss: 0.3737 - val_accuracy: 0.8525
# Epoch 218/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1982 - accuracy: 0.9146 - val_loss: 0.3523 - val_accuracy: 0.8586
# Epoch 219/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1935 - accuracy: 0.9168 - val_loss: 0.3493 - val_accuracy: 0.8598
# Epoch 220/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1946 - accuracy: 0.9165 - val_loss: 0.3330 - val_accuracy: 0.8645
# Epoch 221/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1942 - accuracy: 0.9164 - val_loss: 0.3452 - val_accuracy: 0.8630
# Epoch 222/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1922 - accuracy: 0.9177 - val_loss: 0.3623 - val_accuracy: 0.8537
# Epoch 223/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1918 - accuracy: 0.9178 - val_loss: 0.3378 - val_accuracy: 0.8625
# Epoch 224/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1955 - accuracy: 0.9159 - val_loss: 0.3390 - val_accuracy: 0.8600
# Epoch 225/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1918 - accuracy: 0.9182 - val_loss: 0.3366 - val_accuracy: 0.8639
# Epoch 226/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1905 - accuracy: 0.9186 - val_loss: 0.3275 - val_accuracy: 0.8659
# Epoch 227/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1864 - accuracy: 0.9200 - val_loss: 0.3305 - val_accuracy: 0.8679
# Epoch 228/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1934 - accuracy: 0.9172 - val_loss: 0.3532 - val_accuracy: 0.8596
# Epoch 229/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1867 - accuracy: 0.9202 - val_loss: 0.3328 - val_accuracy: 0.8678
# Epoch 230/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1886 - accuracy: 0.9196 - val_loss: 0.3467 - val_accuracy: 0.8617
# Epoch 231/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1894 - accuracy: 0.9189 - val_loss: 0.3211 - val_accuracy: 0.8689
# Epoch 232/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1872 - accuracy: 0.9202 - val_loss: 0.3354 - val_accuracy: 0.8650
# Epoch 233/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1871 - accuracy: 0.9203 - val_loss: 0.3182 - val_accuracy: 0.8708
# Epoch 234/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1841 - accuracy: 0.9218 - val_loss: 0.3282 - val_accuracy: 0.8709
# Epoch 235/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1872 - accuracy: 0.9198 - val_loss: 0.3261 - val_accuracy: 0.8672
# Epoch 236/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1854 - accuracy: 0.9209 - val_loss: 0.3394 - val_accuracy: 0.8625
# Epoch 237/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1860 - accuracy: 0.9204 - val_loss: 0.3268 - val_accuracy: 0.8672
# Epoch 238/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1830 - accuracy: 0.9219 - val_loss: 0.3293 - val_accuracy: 0.8678
# Epoch 239/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1833 - accuracy: 0.9218 - val_loss: 0.3397 - val_accuracy: 0.8660
# Epoch 240/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1853 - accuracy: 0.9209 - val_loss: 0.3232 - val_accuracy: 0.8697
# Epoch 241/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1783 - accuracy: 0.9243 - val_loss: 0.3255 - val_accuracy: 0.8699
# Epoch 242/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1819 - accuracy: 0.9229 - val_loss: 0.3451 - val_accuracy: 0.8632
# Epoch 243/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1842 - accuracy: 0.9217 - val_loss: 0.3144 - val_accuracy: 0.8731
# Epoch 244/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1773 - accuracy: 0.9245 - val_loss: 0.3858 - val_accuracy: 0.8429
# Epoch 245/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1808 - accuracy: 0.9229 - val_loss: 0.3246 - val_accuracy: 0.8723
# Epoch 246/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1785 - accuracy: 0.9238 - val_loss: 0.3262 - val_accuracy: 0.8674
# Epoch 247/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1788 - accuracy: 0.9234 - val_loss: 0.3720 - val_accuracy: 0.8535
# Epoch 248/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1759 - accuracy: 0.9249 - val_loss: 0.3378 - val_accuracy: 0.8681
# Epoch 249/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1788 - accuracy: 0.9239 - val_loss: 0.3381 - val_accuracy: 0.8682
# Epoch 250/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1795 - accuracy: 0.9239 - val_loss: 0.3342 - val_accuracy: 0.8722
# Epoch 251/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1750 - accuracy: 0.9255 - val_loss: 0.3352 - val_accuracy: 0.8665
# Epoch 252/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1749 - accuracy: 0.9260 - val_loss: 0.3190 - val_accuracy: 0.8745
# Epoch 253/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1748 - accuracy: 0.9256 - val_loss: 0.3325 - val_accuracy: 0.8696
# Epoch 254/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1791 - accuracy: 0.9238 - val_loss: 0.3406 - val_accuracy: 0.8687
# Epoch 255/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1718 - accuracy: 0.9271 - val_loss: 0.3298 - val_accuracy: 0.8721
# Epoch 256/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1756 - accuracy: 0.9252 - val_loss: 0.3222 - val_accuracy: 0.8732
# Epoch 257/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1712 - accuracy: 0.9276 - val_loss: 0.3265 - val_accuracy: 0.8700
# Epoch 258/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1729 - accuracy: 0.9267 - val_loss: 0.3294 - val_accuracy: 0.8732
# Epoch 259/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1744 - accuracy: 0.9261 - val_loss: 0.3287 - val_accuracy: 0.8741
# Epoch 260/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1725 - accuracy: 0.9271 - val_loss: 0.3487 - val_accuracy: 0.8630
# Epoch 261/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1714 - accuracy: 0.9275 - val_loss: 0.3245 - val_accuracy: 0.8749
# Epoch 262/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1706 - accuracy: 0.9281 - val_loss: 0.3973 - val_accuracy: 0.8461
# Epoch 263/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1697 - accuracy: 0.9284 - val_loss: 0.3364 - val_accuracy: 0.8715
# Epoch 264/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1714 - accuracy: 0.9277 - val_loss: 0.3192 - val_accuracy: 0.8755
# Epoch 265/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1711 - accuracy: 0.9275 - val_loss: 0.3301 - val_accuracy: 0.8727
# Epoch 266/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1666 - accuracy: 0.9294 - val_loss: 0.3204 - val_accuracy: 0.8775
# Epoch 267/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1698 - accuracy: 0.9285 - val_loss: 0.3312 - val_accuracy: 0.8697
# Epoch 268/500
# 546/546 [==============================] - 2s 4ms/step - loss: 0.1665 - accuracy: 0.9297 - val_loss: 0.3205 - val_accuracy: 0.8756
# Epoch 269/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1638 - accuracy: 0.9309 - val_loss: 0.3713 - val_accuracy: 0.8570
# Epoch 270/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1681 - accuracy: 0.9288 - val_loss: 0.3258 - val_accuracy: 0.8737
# Epoch 271/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1647 - accuracy: 0.9305 - val_loss: 0.3240 - val_accuracy: 0.8768
# Epoch 272/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1701 - accuracy: 0.9281 - val_loss: 0.3347 - val_accuracy: 0.8694
# Epoch 273/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1639 - accuracy: 0.9308 - val_loss: 0.3219 - val_accuracy: 0.8762
# Training Time:  741.1256296634674 seconds

# %% [markdown]
# # Saving the model and training history

# %%
ann_model.save('ANN_Architecture_30_Features.h5')
np.save('ANN_history_30_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of Artificial Neural Network - 30 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of Artificial Neural Network - 30 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred = ann_model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 19s 4ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = ann_model.evaluate(X_test, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.78, Test loss: 0.47

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.78     77586
#            1       0.78      0.77      0.78     77704
#
#     accuracy                           0.78    155290
#    macro avg       0.78      0.78      0.78    155290
# weighted avg       0.78      0.78      0.78    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix ANN - 30 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.7757228411359393
# Precision: 0.7767050441427023
# Recall: 0.7744260269741583
# F1-score: 0.7755638613223353
# AUC-ROC: 0.7757238272936937

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
roc_data['ANN - 30'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()

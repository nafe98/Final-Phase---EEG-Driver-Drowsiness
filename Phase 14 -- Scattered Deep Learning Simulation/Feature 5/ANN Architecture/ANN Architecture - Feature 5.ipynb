# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 5/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 5/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 5/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 5/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - ANN</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# # 1. Network Initialization

# %%
input_dim = X_train.shape[1]  

batch_size = 1024 
epochs = 500  
learning_rate = 0.0001  
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# # 2. Define Architecture

# %%
ann_model = Sequential([
    
    Dense(2048, input_dim=input_dim, activation='relu'),
    Dense(1024, activation='relu'),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid') 
    
])

# %%
ann_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2048)              12288
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dense_6 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,807,809
# Trainable params: 2,807,809
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
ann_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# # Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/ANN_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = ann_model.fit(X_train, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping],  
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6633 - accuracy: 0.5932
# Epoch 1: val_loss improved from inf to 0.65898, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 39s 66ms/step - loss: 0.6633 - accuracy: 0.5932 - val_loss: 0.6590 - val_accuracy: 0.6019
# Epoch 2/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6551 - accuracy: 0.6065
# Epoch 2: val_loss improved from 0.65898 to 0.65481, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 64ms/step - loss: 0.6551 - accuracy: 0.6065 - val_loss: 0.6548 - val_accuracy: 0.6073
# Epoch 3/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6518 - accuracy: 0.6113
# Epoch 3: val_loss improved from 0.65481 to 0.65057, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 63ms/step - loss: 0.6518 - accuracy: 0.6113 - val_loss: 0.6506 - val_accuracy: 0.6129
# Epoch 4/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.6496 - accuracy: 0.6137
# Epoch 4: val_loss did not improve from 0.65057
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6496 - accuracy: 0.6137 - val_loss: 0.6518 - val_accuracy: 0.6108
# Epoch 5/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.6481 - accuracy: 0.6153
# Epoch 5: val_loss improved from 0.65057 to 0.64782, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 63ms/step - loss: 0.6480 - accuracy: 0.6153 - val_loss: 0.6478 - val_accuracy: 0.6152
# Epoch 6/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6464 - accuracy: 0.6174
# Epoch 6: val_loss improved from 0.64782 to 0.64679, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 64ms/step - loss: 0.6464 - accuracy: 0.6174 - val_loss: 0.6468 - val_accuracy: 0.6169
# Epoch 7/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6452 - accuracy: 0.6184
# Epoch 7: val_loss improved from 0.64679 to 0.64639, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 35s 63ms/step - loss: 0.6452 - accuracy: 0.6184 - val_loss: 0.6464 - val_accuracy: 0.6180
# Epoch 8/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6438 - accuracy: 0.6195
# Epoch 8: val_loss improved from 0.64639 to 0.64530, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6438 - accuracy: 0.6195 - val_loss: 0.6453 - val_accuracy: 0.6190
# Epoch 9/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6426 - accuracy: 0.6205
# Epoch 9: val_loss improved from 0.64530 to 0.64459, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6426 - accuracy: 0.6205 - val_loss: 0.6446 - val_accuracy: 0.6195
# Epoch 10/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6415 - accuracy: 0.6215
# Epoch 10: val_loss improved from 0.64459 to 0.64257, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6415 - accuracy: 0.6215 - val_loss: 0.6426 - val_accuracy: 0.6212
# Epoch 11/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6407 - accuracy: 0.6219
# Epoch 11: val_loss did not improve from 0.64257
# 546/546 [==============================] - 34s 62ms/step - loss: 0.6407 - accuracy: 0.6219 - val_loss: 0.6429 - val_accuracy: 0.6205
# Epoch 12/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.6395 - accuracy: 0.6232
# Epoch 12: val_loss improved from 0.64257 to 0.64140, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6395 - accuracy: 0.6232 - val_loss: 0.6414 - val_accuracy: 0.6233
# Epoch 13/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.6388 - accuracy: 0.6242
# Epoch 13: val_loss did not improve from 0.64140
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6388 - accuracy: 0.6241 - val_loss: 0.6422 - val_accuracy: 0.6211
# Epoch 14/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6380 - accuracy: 0.6247
# Epoch 14: val_loss did not improve from 0.64140
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6380 - accuracy: 0.6247 - val_loss: 0.6415 - val_accuracy: 0.6201
# Epoch 15/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6372 - accuracy: 0.6256
# Epoch 15: val_loss improved from 0.64140 to 0.64000, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6372 - accuracy: 0.6256 - val_loss: 0.6400 - val_accuracy: 0.6229
# Epoch 16/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6364 - accuracy: 0.6260
# Epoch 16: val_loss did not improve from 0.64000
# 546/546 [==============================] - 34s 62ms/step - loss: 0.6364 - accuracy: 0.6260 - val_loss: 0.6404 - val_accuracy: 0.6237
# Epoch 17/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6359 - accuracy: 0.6262
# Epoch 17: val_loss did not improve from 0.64000
# 546/546 [==============================] - 34s 62ms/step - loss: 0.6359 - accuracy: 0.6262 - val_loss: 0.6402 - val_accuracy: 0.6221
# Epoch 18/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6351 - accuracy: 0.6268
# Epoch 18: val_loss improved from 0.64000 to 0.63952, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6351 - accuracy: 0.6268 - val_loss: 0.6395 - val_accuracy: 0.6222
# Epoch 19/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6344 - accuracy: 0.6273
# Epoch 19: val_loss improved from 0.63952 to 0.63931, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6344 - accuracy: 0.6273 - val_loss: 0.6393 - val_accuracy: 0.6220
# Epoch 20/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6338 - accuracy: 0.6280
# Epoch 20: val_loss did not improve from 0.63931
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6338 - accuracy: 0.6280 - val_loss: 0.6395 - val_accuracy: 0.6225
# Epoch 21/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6332 - accuracy: 0.6282
# Epoch 21: val_loss improved from 0.63931 to 0.63922, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6332 - accuracy: 0.6282 - val_loss: 0.6392 - val_accuracy: 0.6228
# Epoch 22/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6328 - accuracy: 0.6284
# Epoch 22: val_loss improved from 0.63922 to 0.63772, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6328 - accuracy: 0.6284 - val_loss: 0.6377 - val_accuracy: 0.6224
# Epoch 23/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6322 - accuracy: 0.6293
# Epoch 23: val_loss did not improve from 0.63772
# 546/546 [==============================] - 34s 62ms/step - loss: 0.6322 - accuracy: 0.6293 - val_loss: 0.6386 - val_accuracy: 0.6226
# Epoch 24/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6318 - accuracy: 0.6296
# Epoch 24: val_loss did not improve from 0.63772
# 546/546 [==============================] - 34s 62ms/step - loss: 0.6318 - accuracy: 0.6296 - val_loss: 0.6381 - val_accuracy: 0.6249
# Epoch 25/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6312 - accuracy: 0.6300
# Epoch 25: val_loss improved from 0.63772 to 0.63762, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6312 - accuracy: 0.6300 - val_loss: 0.6376 - val_accuracy: 0.6235
# Epoch 26/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.6308 - accuracy: 0.6304
# Epoch 26: val_loss did not improve from 0.63762
# 546/546 [==============================] - 34s 62ms/step - loss: 0.6308 - accuracy: 0.6304 - val_loss: 0.6377 - val_accuracy: 0.6245
# Epoch 27/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6301 - accuracy: 0.6311
# Epoch 27: val_loss did not improve from 0.63762
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6301 - accuracy: 0.6311 - val_loss: 0.6391 - val_accuracy: 0.6217
# Epoch 28/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6297 - accuracy: 0.6313
# Epoch 28: val_loss improved from 0.63762 to 0.63760, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6297 - accuracy: 0.6313 - val_loss: 0.6376 - val_accuracy: 0.6224
# Epoch 29/500
# 545/546 [============================>.] - ETA: 0s - loss: 0.6293 - accuracy: 0.6312
# Epoch 29: val_loss did not improve from 0.63760
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6293 - accuracy: 0.6312 - val_loss: 0.6379 - val_accuracy: 0.6245
# Epoch 30/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6288 - accuracy: 0.6317
# Epoch 30: val_loss improved from 0.63760 to 0.63724, saving model to /Model Checkpoints\ANN_Model_Checkpoint.h5
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6288 - accuracy: 0.6317 - val_loss: 0.6372 - val_accuracy: 0.6230
# Epoch 31/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6282 - accuracy: 0.6325
# Epoch 31: val_loss did not improve from 0.63724
# 546/546 [==============================] - 35s 63ms/step - loss: 0.6282 - accuracy: 0.6325 - val_loss: 0.6387 - val_accuracy: 0.6216
# Epoch 32/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6280 - accuracy: 0.6324
# Epoch 32: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6280 - accuracy: 0.6324 - val_loss: 0.6384 - val_accuracy: 0.6224
# Epoch 33/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6275 - accuracy: 0.6333
# Epoch 33: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6275 - accuracy: 0.6333 - val_loss: 0.6394 - val_accuracy: 0.6249
# Epoch 34/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6271 - accuracy: 0.6330
# Epoch 34: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6271 - accuracy: 0.6330 - val_loss: 0.6385 - val_accuracy: 0.6223
# Epoch 35/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6265 - accuracy: 0.6340
# Epoch 35: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6265 - accuracy: 0.6340 - val_loss: 0.6389 - val_accuracy: 0.6230
# Epoch 36/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6260 - accuracy: 0.6344
# Epoch 36: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 62ms/step - loss: 0.6260 - accuracy: 0.6344 - val_loss: 0.6393 - val_accuracy: 0.6200
# Epoch 37/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6259 - accuracy: 0.6346
# Epoch 37: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6259 - accuracy: 0.6346 - val_loss: 0.6414 - val_accuracy: 0.6202
# Epoch 38/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6252 - accuracy: 0.6353
# Epoch 38: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6252 - accuracy: 0.6353 - val_loss: 0.6378 - val_accuracy: 0.6223
# Epoch 39/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6249 - accuracy: 0.6351
# Epoch 39: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6249 - accuracy: 0.6351 - val_loss: 0.6375 - val_accuracy: 0.6224
# Epoch 40/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6247 - accuracy: 0.6355
# Epoch 40: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6247 - accuracy: 0.6355 - val_loss: 0.6382 - val_accuracy: 0.6205
# Epoch 41/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6239 - accuracy: 0.6365
# Epoch 41: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6239 - accuracy: 0.6365 - val_loss: 0.6391 - val_accuracy: 0.6204
# Epoch 42/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6237 - accuracy: 0.6367
# Epoch 42: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6237 - accuracy: 0.6367 - val_loss: 0.6386 - val_accuracy: 0.6231
# Epoch 43/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6231 - accuracy: 0.6369
# Epoch 43: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6231 - accuracy: 0.6369 - val_loss: 0.6396 - val_accuracy: 0.6213
# Epoch 44/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6226 - accuracy: 0.6371
# Epoch 44: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6226 - accuracy: 0.6371 - val_loss: 0.6411 - val_accuracy: 0.6202
# Epoch 45/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6224 - accuracy: 0.6371
# Epoch 45: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6224 - accuracy: 0.6371 - val_loss: 0.6396 - val_accuracy: 0.6204
# Epoch 46/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6218 - accuracy: 0.6382
# Epoch 46: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6218 - accuracy: 0.6382 - val_loss: 0.6388 - val_accuracy: 0.6217
# Epoch 47/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6213 - accuracy: 0.6391
# Epoch 47: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6213 - accuracy: 0.6391 - val_loss: 0.6402 - val_accuracy: 0.6194
# Epoch 48/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6209 - accuracy: 0.6386
# Epoch 48: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6209 - accuracy: 0.6386 - val_loss: 0.6409 - val_accuracy: 0.6199
# Epoch 49/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6204 - accuracy: 0.6395
# Epoch 49: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6204 - accuracy: 0.6395 - val_loss: 0.6405 - val_accuracy: 0.6201
# Epoch 50/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6200 - accuracy: 0.6399
# Epoch 50: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6200 - accuracy: 0.6399 - val_loss: 0.6415 - val_accuracy: 0.6196
# Epoch 51/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6195 - accuracy: 0.6404
# Epoch 51: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6195 - accuracy: 0.6404 - val_loss: 0.6411 - val_accuracy: 0.6190
# Epoch 52/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6191 - accuracy: 0.6410
# Epoch 52: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6191 - accuracy: 0.6410 - val_loss: 0.6432 - val_accuracy: 0.6177
# Epoch 53/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6187 - accuracy: 0.6417
# Epoch 53: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6187 - accuracy: 0.6417 - val_loss: 0.6413 - val_accuracy: 0.6202
# Epoch 54/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6182 - accuracy: 0.6423
# Epoch 54: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6182 - accuracy: 0.6423 - val_loss: 0.6423 - val_accuracy: 0.6185
# Epoch 55/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6176 - accuracy: 0.6420
# Epoch 55: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6176 - accuracy: 0.6420 - val_loss: 0.6427 - val_accuracy: 0.6189
# Epoch 56/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6172 - accuracy: 0.6424
# Epoch 56: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6172 - accuracy: 0.6424 - val_loss: 0.6435 - val_accuracy: 0.6181
# Epoch 57/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6167 - accuracy: 0.6428
# Epoch 57: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6167 - accuracy: 0.6428 - val_loss: 0.6436 - val_accuracy: 0.6168
# Epoch 58/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6163 - accuracy: 0.6434
# Epoch 58: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6163 - accuracy: 0.6434 - val_loss: 0.6430 - val_accuracy: 0.6182
# Epoch 59/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6157 - accuracy: 0.6442
# Epoch 59: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6157 - accuracy: 0.6442 - val_loss: 0.6434 - val_accuracy: 0.6181
# Epoch 60/500
# 546/546 [==============================] - ETA: 0s - loss: 0.6153 - accuracy: 0.6446
# Epoch 60: val_loss did not improve from 0.63724
# 546/546 [==============================] - 34s 63ms/step - loss: 0.6153 - accuracy: 0.6446 - val_loss: 0.6449 - val_accuracy: 0.6181
# Training Time:  2065.0531797409058 seconds

# %% [markdown]
# # Saving the model and training history

# %%
ann_model.save('ANN_Architecture_5_Features.h5')
np.save('ANN_history_5_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of Artificial Neural Network - 5 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of Artificial Neural Network - 5 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred = ann_model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 23s 5ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = ann_model.evaluate(X_test, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.62, Test loss: 0.64

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.66      0.64     77586
#            1       0.63      0.59      0.61     77704
#
#     accuracy                           0.62    155290
#    macro avg       0.62      0.62      0.62    155290
# weighted avg       0.62      0.62      0.62    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix ANN - 5 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.6236654002189452
# Precision: 0.6324372636644895
# Recall: 0.591912900236796
# F1-score: 0.6115044306616411
# AUC-ROC: 0.6236895462955433

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
roc_data['ANN - 5'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 5/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 5/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 5/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 5/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - LSTM</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
from keras.layers import LSTM
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for LSTM

# %%
X_train_array = X_train
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (5, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# # 2. Define Architecture

# %%
lstm_model = Sequential([
    
    LSTM(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1), 
    LSTM(256, activation='relu'),
    Dropout(0.1),  
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 5, 512)            1052672
#
#  dropout (Dropout)           (None, 5, 512)            0
#
#  lstm_1 (LSTM)               (None, 256)               787456
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,840,385
# Trainable params: 1,840,385
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
lstm_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# ## Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/LSTM_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = lstm_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping],  
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6630 - accuracy: 0.5963
# Epoch 1: val_loss improved from inf to 0.65419, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 231s 285ms/step - loss: 0.6630 - accuracy: 0.5963 - val_loss: 0.6542 - val_accuracy: 0.6105
# Epoch 2/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6517 - accuracy: 0.6111
# Epoch 2: val_loss improved from 0.65419 to 0.65036, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6517 - accuracy: 0.6111 - val_loss: 0.6504 - val_accuracy: 0.6139
# Epoch 3/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6485 - accuracy: 0.6143
# Epoch 3: val_loss improved from 0.65036 to 0.64713, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6485 - accuracy: 0.6143 - val_loss: 0.6471 - val_accuracy: 0.6161
# Epoch 4/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6454 - accuracy: 0.6174
# Epoch 4: val_loss improved from 0.64713 to 0.64396, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6454 - accuracy: 0.6174 - val_loss: 0.6440 - val_accuracy: 0.6188
# Epoch 5/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6422 - accuracy: 0.6205
# Epoch 5: val_loss improved from 0.64396 to 0.64074, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6422 - accuracy: 0.6205 - val_loss: 0.6407 - val_accuracy: 0.6228
# Epoch 6/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6393 - accuracy: 0.6224
# Epoch 6: val_loss improved from 0.64074 to 0.63966, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6393 - accuracy: 0.6224 - val_loss: 0.6397 - val_accuracy: 0.6217
# Epoch 7/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6369 - accuracy: 0.6240
# Epoch 7: val_loss improved from 0.63966 to 0.63740, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6369 - accuracy: 0.6240 - val_loss: 0.6374 - val_accuracy: 0.6228
# Epoch 8/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6351 - accuracy: 0.6249
# Epoch 8: val_loss improved from 0.63740 to 0.63677, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 285ms/step - loss: 0.6351 - accuracy: 0.6249 - val_loss: 0.6368 - val_accuracy: 0.6248
# Epoch 9/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6345 - accuracy: 0.6259
# Epoch 9: val_loss did not improve from 0.63677
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6345 - accuracy: 0.6259 - val_loss: 0.6368 - val_accuracy: 0.6245
# Epoch 10/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6333 - accuracy: 0.6268
# Epoch 10: val_loss improved from 0.63677 to 0.63594, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6333 - accuracy: 0.6268 - val_loss: 0.6359 - val_accuracy: 0.6262
# Epoch 11/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6326 - accuracy: 0.6270
# Epoch 11: val_loss improved from 0.63594 to 0.63464, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 227s 285ms/step - loss: 0.6326 - accuracy: 0.6270 - val_loss: 0.6346 - val_accuracy: 0.6249
# Epoch 12/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6318 - accuracy: 0.6281
# Epoch 12: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6318 - accuracy: 0.6281 - val_loss: 0.6356 - val_accuracy: 0.6243
# Epoch 13/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6313 - accuracy: 0.6277
# Epoch 13: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6313 - accuracy: 0.6277 - val_loss: 0.6353 - val_accuracy: 0.6266
# Epoch 14/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6306 - accuracy: 0.6287
# Epoch 14: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6306 - accuracy: 0.6287 - val_loss: 0.6349 - val_accuracy: 0.6249
# Epoch 15/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6300 - accuracy: 0.6293
# Epoch 15: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6300 - accuracy: 0.6293 - val_loss: 0.6351 - val_accuracy: 0.6259
# Epoch 16/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6296 - accuracy: 0.6296
# Epoch 16: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6296 - accuracy: 0.6296 - val_loss: 0.6353 - val_accuracy: 0.6257
# Epoch 17/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6288 - accuracy: 0.6299
# Epoch 17: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6288 - accuracy: 0.6299 - val_loss: 0.6358 - val_accuracy: 0.6260
# Epoch 18/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6286 - accuracy: 0.6301
# Epoch 18: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6286 - accuracy: 0.6301 - val_loss: 0.6358 - val_accuracy: 0.6256
# Epoch 19/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6278 - accuracy: 0.6307
# Epoch 19: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6278 - accuracy: 0.6307 - val_loss: 0.6355 - val_accuracy: 0.6253
# Epoch 20/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6271 - accuracy: 0.6312
# Epoch 20: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6271 - accuracy: 0.6312 - val_loss: 0.6379 - val_accuracy: 0.6256
# Epoch 21/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6263 - accuracy: 0.6317
# Epoch 21: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6263 - accuracy: 0.6317 - val_loss: 0.6367 - val_accuracy: 0.6258
# Epoch 22/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6260 - accuracy: 0.6319
# Epoch 22: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6260 - accuracy: 0.6319 - val_loss: 0.6376 - val_accuracy: 0.6261
# Epoch 23/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6251 - accuracy: 0.6328
# Epoch 23: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6251 - accuracy: 0.6328 - val_loss: 0.6367 - val_accuracy: 0.6245
# Epoch 24/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6244 - accuracy: 0.6333
# Epoch 24: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6244 - accuracy: 0.6333 - val_loss: 0.6377 - val_accuracy: 0.6244
# Epoch 25/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6237 - accuracy: 0.6340
# Epoch 25: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 285ms/step - loss: 0.6237 - accuracy: 0.6340 - val_loss: 0.6381 - val_accuracy: 0.6238
# Epoch 26/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6230 - accuracy: 0.6341
# Epoch 26: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6230 - accuracy: 0.6341 - val_loss: 0.6379 - val_accuracy: 0.6257
# Epoch 27/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6223 - accuracy: 0.6352
# Epoch 27: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 285ms/step - loss: 0.6223 - accuracy: 0.6352 - val_loss: 0.6398 - val_accuracy: 0.6243
# Epoch 28/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6210 - accuracy: 0.6363
# Epoch 28: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6210 - accuracy: 0.6363 - val_loss: 0.6418 - val_accuracy: 0.6251
# Epoch 29/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6205 - accuracy: 0.6363
# Epoch 29: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6205 - accuracy: 0.6363 - val_loss: 0.6421 - val_accuracy: 0.6248
# Epoch 30/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6191 - accuracy: 0.6375
# Epoch 30: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6191 - accuracy: 0.6375 - val_loss: 0.6438 - val_accuracy: 0.6249
# Epoch 31/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6181 - accuracy: 0.6377
# Epoch 31: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6181 - accuracy: 0.6377 - val_loss: 0.6429 - val_accuracy: 0.6235
# Epoch 32/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6169 - accuracy: 0.6392
# Epoch 32: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6169 - accuracy: 0.6392 - val_loss: 0.6459 - val_accuracy: 0.6224
# Epoch 33/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6164 - accuracy: 0.6394
# Epoch 33: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 285ms/step - loss: 0.6164 - accuracy: 0.6394 - val_loss: 0.6477 - val_accuracy: 0.6221
# Epoch 34/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6147 - accuracy: 0.6411
# Epoch 34: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6147 - accuracy: 0.6411 - val_loss: 0.6475 - val_accuracy: 0.6227
# Epoch 35/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6135 - accuracy: 0.6416
# Epoch 35: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6135 - accuracy: 0.6416 - val_loss: 0.6504 - val_accuracy: 0.6227
# Epoch 36/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6120 - accuracy: 0.6429
# Epoch 36: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6120 - accuracy: 0.6429 - val_loss: 0.6501 - val_accuracy: 0.6217
# Epoch 37/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6103 - accuracy: 0.6443
# Epoch 37: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6103 - accuracy: 0.6443 - val_loss: 0.6532 - val_accuracy: 0.6207
# Epoch 38/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6093 - accuracy: 0.6451
# Epoch 38: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6093 - accuracy: 0.6451 - val_loss: 0.6553 - val_accuracy: 0.6196
# Epoch 39/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6076 - accuracy: 0.6459
# Epoch 39: val_loss did not improve from 0.63464
# 799/799 [==============================] - 226s 283ms/step - loss: 0.6076 - accuracy: 0.6459 - val_loss: 0.6560 - val_accuracy: 0.6214
# Epoch 40/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6061 - accuracy: 0.6475
# Epoch 40: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6061 - accuracy: 0.6475 - val_loss: 0.6583 - val_accuracy: 0.6191
# Epoch 41/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6042 - accuracy: 0.6490
# Epoch 41: val_loss did not improve from 0.63464
# 799/799 [==============================] - 227s 284ms/step - loss: 0.6042 - accuracy: 0.6490 - val_loss: 0.6622 - val_accuracy: 0.6191
# Training Time:  9311.603754520416 seconds
# Epoch 169/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.2236 - accuracy: 0.9093 - val_loss: 0.2991 - val_accuracy: 0.8778
# Epoch 170/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.2149 - accuracy: 0.9119 - val_loss: 0.3086 - val_accuracy: 0.8750
# Epoch 171/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1998 - accuracy: 0.9132 - val_loss: 0.2951 - val_accuracy: 0.8799
# Epoch 172/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1963 - accuracy: 0.9145 - val_loss: 0.2963 - val_accuracy: 0.8793
# Epoch 173/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1937 - accuracy: 0.9150 - val_loss: 0.2983 - val_accuracy: 0.8796
# Epoch 174/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1903 - accuracy: 0.9164 - val_loss: 0.2913 - val_accuracy: 0.8816
# Epoch 175/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1911 - accuracy: 0.9163 - val_loss: 0.2920 - val_accuracy: 0.8823
# Epoch 176/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.1896 - accuracy: 0.9170 - val_loss: 0.2981 - val_accuracy: 0.8809
# Epoch 177/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1900 - accuracy: 0.9169 - val_loss: 0.2995 - val_accuracy: 0.8801
# Epoch 178/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1926 - accuracy: 0.9161 - val_loss: 0.2909 - val_accuracy: 0.8814
# Epoch 179/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1893 - accuracy: 0.9171 - val_loss: 0.2903 - val_accuracy: 0.8836
# Epoch 180/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1890 - accuracy: 0.9176 - val_loss: 0.2945 - val_accuracy: 0.8804
# Epoch 181/500
# 799/799 [==============================] - 19s 23ms/step - loss: 0.1863 - accuracy: 0.9182 - val_loss: 0.2940 - val_accuracy: 0.8822
# Epoch 182/500
# 799/799 [==============================] - 19s 23ms/step - loss: 0.1854 - accuracy: 0.9193 - val_loss: 0.2916 - val_accuracy: 0.8834
# Epoch 183/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.1882 - accuracy: 0.9184 - val_loss: 0.2903 - val_accuracy: 0.8833
# Epoch 184/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.1861 - accuracy: 0.9190 - val_loss: 0.2956 - val_accuracy: 0.8821
# Epoch 185/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1893 - accuracy: 0.9179 - val_loss: 0.2924 - val_accuracy: 0.8835
# Epoch 186/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1838 - accuracy: 0.9199 - val_loss: 0.2878 - val_accuracy: 0.8853
# Epoch 187/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.1812 - accuracy: 0.9208 - val_loss: 0.2940 - val_accuracy: 0.8836
# Epoch 188/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1869 - accuracy: 0.9198 - val_loss: 0.2979 - val_accuracy: 0.8839
# Epoch 189/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1834 - accuracy: 0.9208 - val_loss: 0.2930 - val_accuracy: 0.8846
# Epoch 190/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1828 - accuracy: 0.9208 - val_loss: 0.2951 - val_accuracy: 0.8848
# Epoch 191/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1797 - accuracy: 0.9222 - val_loss: 0.2952 - val_accuracy: 0.8854
# Epoch 192/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1780 - accuracy: 0.9225 - val_loss: 0.2902 - val_accuracy: 0.8839
# Epoch 193/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1794 - accuracy: 0.9224 - val_loss: 0.2954 - val_accuracy: 0.8856
# Epoch 194/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1793 - accuracy: 0.9225 - val_loss: 0.2906 - val_accuracy: 0.8865
# Epoch 195/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1768 - accuracy: 0.9229 - val_loss: 0.2956 - val_accuracy: 0.8845
# Epoch 196/500
# 799/799 [==============================] - 20s 24ms/step - loss: 0.1769 - accuracy: 0.9230 - val_loss: 0.2912 - val_accuracy: 0.8844
# Epoch 197/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1763 - accuracy: 0.9237 - val_loss: 0.2936 - val_accuracy: 0.8861
# Epoch 198/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1786 - accuracy: 0.9231 - val_loss: 0.2919 - val_accuracy: 0.8853
# Epoch 199/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1774 - accuracy: 0.9237 - val_loss: 0.2957 - val_accuracy: 0.8851
# Epoch 200/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1752 - accuracy: 0.9244 - val_loss: 0.2915 - val_accuracy: 0.8866
# Epoch 201/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1738 - accuracy: 0.9248 - val_loss: 0.2927 - val_accuracy: 0.8861
# Epoch 202/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1747 - accuracy: 0.9247 - val_loss: 0.3182 - val_accuracy: 0.8753
# Epoch 203/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1775 - accuracy: 0.9237 - val_loss: 0.2931 - val_accuracy: 0.8860
# Epoch 204/500
# 799/799 [==============================] - 20s 26ms/step - loss: 0.1723 - accuracy: 0.9253 - val_loss: 0.2937 - val_accuracy: 0.8868
# Epoch 205/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1786 - accuracy: 0.9234 - val_loss: 0.2929 - val_accuracy: 0.8866
# Epoch 206/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1742 - accuracy: 0.9256 - val_loss: 0.2946 - val_accuracy: 0.8869
# Epoch 207/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1756 - accuracy: 0.9249 - val_loss: 0.2977 - val_accuracy: 0.8857
# Epoch 208/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1711 - accuracy: 0.9267 - val_loss: 0.2894 - val_accuracy: 0.8877
# Epoch 209/500
# 799/799 [==============================] - 21s 26ms/step - loss: 0.1708 - accuracy: 0.9267 - val_loss: 0.2937 - val_accuracy: 0.8863
# Epoch 210/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1713 - accuracy: 0.9264 - val_loss: 0.2966 - val_accuracy: 0.8860
# Epoch 211/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1714 - accuracy: 0.9263 - val_loss: 0.2967 - val_accuracy: 0.8865
# Epoch 212/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1699 - accuracy: 0.9269 - val_loss: 0.2942 - val_accuracy: 0.8876
# Epoch 213/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1672 - accuracy: 0.9282 - val_loss: 0.2923 - val_accuracy: 0.8882
# Epoch 214/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1701 - accuracy: 0.9270 - val_loss: 0.2963 - val_accuracy: 0.8871
# Epoch 215/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1683 - accuracy: 0.9277 - val_loss: 0.2918 - val_accuracy: 0.8879
# Epoch 216/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1680 - accuracy: 0.9278 - val_loss: 0.2916 - val_accuracy: 0.8880
# Training Time:  4259.20539855957 seconds

# %% [markdown]
# # Saving the model and training history

# %%
lstm_model.save('LSTM_Architecture_5_Features.h5')
np.save('LSTM_history_5_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of LSTM Neural Network - 5 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of LSTM Neural Network - 5 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for LSTM Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[-5.47251734e-01],
#         [-6.70051216e+00],
#         [-3.53210347e+00],
#         [-3.57554785e+00],
#         [-5.43491299e-04]],
#
#        [[ 1.51066078e+01],
#         [ 1.28901519e+01],
#         [ 9.38198263e+00],
#         [ 9.26921098e+00],
#         [ 4.60932318e+00]],
#
#        [[ 2.93699623e+00],
#         [ 4.82312356e-01],
#         [ 3.60238997e+00],
#         [ 1.55325021e+00],
#         [ 3.03395793e+00]],
#
#        ...,
#
#        [[-2.06647329e+00],
#         [-7.33303830e+00],
#         [-3.58371377e+00],
#         [-3.62013828e+00],
#         [-8.29692600e+00]],
#
#        [[ 2.22265807e+01],
#         [ 2.53946065e+01],
#         [ 1.44652072e+01],
#         [ 1.12923073e+01],
#         [ 2.03065733e+01]],
#
#        [[-1.10987164e+01],
#         [-3.76626649e+00],
#         [-3.26445408e-01],
#         [-1.70854942e+00],
#         [-1.16028270e+00]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = lstm_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 54s 11ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = lstm_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.63, Test loss: 0.63

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.66      0.64     77586
#            1       0.63      0.59      0.61     77704
#
#     accuracy                           0.63    155290
#    macro avg       0.63      0.63      0.63    155290
# weighted avg       0.63      0.63      0.63    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix LSTM - 5 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.6255264344130337
# Precision: 0.6343817012151537
# Recall: 0.5939205188922063
# F1-score: 0.6134846994390237
# AUC-ROC: 0.6820853244251593

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['LSTM - 5'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()

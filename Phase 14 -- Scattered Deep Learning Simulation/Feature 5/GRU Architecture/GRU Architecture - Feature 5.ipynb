# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 5/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 5/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 5/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 5/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - GRU</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from tensorflow.keras.layers import GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for GRU

# %%
X_train_array = X_train  
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (5, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001

# %% [markdown]
# # 2. Define Architecture

# %%
gru_model = Sequential([
    
    GRU(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1),
    GRU(256, activation='relu'),
    Dropout(0.1),
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
gru_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 5, 512)            791040
#
#  dropout (Dropout)           (None, 5, 512)            0
#
#  gru_1 (GRU)                 (None, 256)               591360
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,382,657
# Trainable params: 1,382,657
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
gru_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Integrating Callbacks</h2>
#
# </div>

# %% [markdown]
# ## EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# ## Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/GRU_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = gru_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping], 
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6615 - accuracy: 0.5980
# Epoch 1: val_loss improved from inf to 0.65095, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 244s 301ms/step - loss: 0.6615 - accuracy: 0.5980 - val_loss: 0.6509 - val_accuracy: 0.6114
# Epoch 2/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6493 - accuracy: 0.6138
# Epoch 2: val_loss improved from 0.65095 to 0.64607, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6493 - accuracy: 0.6138 - val_loss: 0.6461 - val_accuracy: 0.6160
# Epoch 3/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6434 - accuracy: 0.6185
# Epoch 3: val_loss improved from 0.64607 to 0.64238, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 239s 300ms/step - loss: 0.6434 - accuracy: 0.6185 - val_loss: 0.6424 - val_accuracy: 0.6194
# Epoch 4/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6399 - accuracy: 0.6211
# Epoch 4: val_loss improved from 0.64238 to 0.63880, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 240s 301ms/step - loss: 0.6399 - accuracy: 0.6211 - val_loss: 0.6388 - val_accuracy: 0.6224
# Epoch 5/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6374 - accuracy: 0.6232
# Epoch 5: val_loss improved from 0.63880 to 0.63767, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 240s 300ms/step - loss: 0.6374 - accuracy: 0.6232 - val_loss: 0.6377 - val_accuracy: 0.6230
# Epoch 6/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6358 - accuracy: 0.6236
# Epoch 6: val_loss improved from 0.63767 to 0.63616, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 240s 300ms/step - loss: 0.6358 - accuracy: 0.6236 - val_loss: 0.6362 - val_accuracy: 0.6249
# Epoch 7/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6345 - accuracy: 0.6249
# Epoch 7: val_loss did not improve from 0.63616
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6345 - accuracy: 0.6249 - val_loss: 0.6365 - val_accuracy: 0.6253
# Epoch 8/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6339 - accuracy: 0.6256
# Epoch 8: val_loss improved from 0.63616 to 0.63560, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 240s 300ms/step - loss: 0.6339 - accuracy: 0.6256 - val_loss: 0.6356 - val_accuracy: 0.6235
# Epoch 9/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6331 - accuracy: 0.6264
# Epoch 9: val_loss did not improve from 0.63560
# 799/799 [==============================] - 240s 300ms/step - loss: 0.6331 - accuracy: 0.6264 - val_loss: 0.6361 - val_accuracy: 0.6237
# Epoch 10/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6324 - accuracy: 0.6264
# Epoch 10: val_loss improved from 0.63560 to 0.63514, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 240s 301ms/step - loss: 0.6324 - accuracy: 0.6264 - val_loss: 0.6351 - val_accuracy: 0.6249
# Epoch 11/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6320 - accuracy: 0.6274
# Epoch 11: val_loss did not improve from 0.63514
# 799/799 [==============================] - 240s 300ms/step - loss: 0.6320 - accuracy: 0.6274 - val_loss: 0.6352 - val_accuracy: 0.6243
# Epoch 12/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6313 - accuracy: 0.6278
# Epoch 12: val_loss did not improve from 0.63514
# 799/799 [==============================] - 240s 301ms/step - loss: 0.6313 - accuracy: 0.6278 - val_loss: 0.6354 - val_accuracy: 0.6238
# Epoch 13/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6308 - accuracy: 0.6283
# Epoch 13: val_loss improved from 0.63514 to 0.63454, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 240s 301ms/step - loss: 0.6308 - accuracy: 0.6283 - val_loss: 0.6345 - val_accuracy: 0.6266
# Epoch 14/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6303 - accuracy: 0.6286
# Epoch 14: val_loss did not improve from 0.63454
# 799/799 [==============================] - 240s 300ms/step - loss: 0.6303 - accuracy: 0.6286 - val_loss: 0.6349 - val_accuracy: 0.6246
# Epoch 15/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6298 - accuracy: 0.6288
# Epoch 15: val_loss improved from 0.63454 to 0.63447, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 240s 301ms/step - loss: 0.6298 - accuracy: 0.6288 - val_loss: 0.6345 - val_accuracy: 0.6244
# Epoch 16/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6294 - accuracy: 0.6294
# Epoch 16: val_loss improved from 0.63447 to 0.63438, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 240s 301ms/step - loss: 0.6294 - accuracy: 0.6294 - val_loss: 0.6344 - val_accuracy: 0.6249
# Epoch 17/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6289 - accuracy: 0.6298
# Epoch 17: val_loss did not improve from 0.63438
# 799/799 [==============================] - 240s 300ms/step - loss: 0.6289 - accuracy: 0.6298 - val_loss: 0.6353 - val_accuracy: 0.6260
# Epoch 18/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6281 - accuracy: 0.6306
# Epoch 18: val_loss did not improve from 0.63438
# 799/799 [==============================] - 240s 300ms/step - loss: 0.6281 - accuracy: 0.6306 - val_loss: 0.6357 - val_accuracy: 0.6258
# Epoch 19/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6276 - accuracy: 0.6306
# Epoch 19: val_loss did not improve from 0.63438
# 799/799 [==============================] - 240s 300ms/step - loss: 0.6276 - accuracy: 0.6306 - val_loss: 0.6364 - val_accuracy: 0.6250
# Epoch 20/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6273 - accuracy: 0.6312
# Epoch 20: val_loss did not improve from 0.63438
# 799/799 [==============================] - 240s 300ms/step - loss: 0.6273 - accuracy: 0.6312 - val_loss: 0.6358 - val_accuracy: 0.6250
# Epoch 21/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6267 - accuracy: 0.6316
# Epoch 21: val_loss did not improve from 0.63438
# 799/799 [==============================] - 240s 300ms/step - loss: 0.6267 - accuracy: 0.6316 - val_loss: 0.6358 - val_accuracy: 0.6250
# Epoch 22/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6256 - accuracy: 0.6325
# Epoch 22: val_loss did not improve from 0.63438
# 799/799 [==============================] - 240s 300ms/step - loss: 0.6256 - accuracy: 0.6325 - val_loss: 0.6358 - val_accuracy: 0.6253
# Epoch 23/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6251 - accuracy: 0.6324
# Epoch 23: val_loss did not improve from 0.63438
# 799/799 [==============================] - 240s 300ms/step - loss: 0.6251 - accuracy: 0.6324 - val_loss: 0.6368 - val_accuracy: 0.6232
# Epoch 24/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6245 - accuracy: 0.6334
# Epoch 24: val_loss did not improve from 0.63438
# 799/799 [==============================] - 240s 301ms/step - loss: 0.6245 - accuracy: 0.6334 - val_loss: 0.6371 - val_accuracy: 0.6229
# Epoch 25/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6236 - accuracy: 0.6343
# Epoch 25: val_loss did not improve from 0.63438
# 799/799 [==============================] - 240s 300ms/step - loss: 0.6236 - accuracy: 0.6343 - val_loss: 0.6371 - val_accuracy: 0.6247
# Epoch 26/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6231 - accuracy: 0.6343
# Epoch 26: val_loss did not improve from 0.63438
# 799/799 [==============================] - 240s 301ms/step - loss: 0.6231 - accuracy: 0.6343 - val_loss: 0.6382 - val_accuracy: 0.6237
# Epoch 27/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6221 - accuracy: 0.6353
# Epoch 27: val_loss did not improve from 0.63438
# 799/799 [==============================] - 240s 301ms/step - loss: 0.6221 - accuracy: 0.6353 - val_loss: 0.6389 - val_accuracy: 0.6247
# Epoch 28/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6213 - accuracy: 0.6361
# Epoch 28: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6213 - accuracy: 0.6361 - val_loss: 0.6390 - val_accuracy: 0.6241
# Epoch 29/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6202 - accuracy: 0.6368
# Epoch 29: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6202 - accuracy: 0.6368 - val_loss: 0.6418 - val_accuracy: 0.6235
# Epoch 30/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6199 - accuracy: 0.6371
# Epoch 30: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6199 - accuracy: 0.6371 - val_loss: 0.6414 - val_accuracy: 0.6230
# Epoch 31/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6187 - accuracy: 0.6381
# Epoch 31: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6187 - accuracy: 0.6381 - val_loss: 0.6413 - val_accuracy: 0.6231
# Epoch 32/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6174 - accuracy: 0.6389
# Epoch 32: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6174 - accuracy: 0.6389 - val_loss: 0.6436 - val_accuracy: 0.6223
# Epoch 33/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6167 - accuracy: 0.6394
# Epoch 33: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6167 - accuracy: 0.6394 - val_loss: 0.6433 - val_accuracy: 0.6222
# Epoch 34/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6152 - accuracy: 0.6410
# Epoch 34: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6152 - accuracy: 0.6410 - val_loss: 0.6462 - val_accuracy: 0.6221
# Epoch 35/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6142 - accuracy: 0.6420
# Epoch 35: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6142 - accuracy: 0.6420 - val_loss: 0.6465 - val_accuracy: 0.6215
# Epoch 36/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6130 - accuracy: 0.6427
# Epoch 36: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6130 - accuracy: 0.6427 - val_loss: 0.6479 - val_accuracy: 0.6219
# Epoch 37/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6117 - accuracy: 0.6437
# Epoch 37: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6117 - accuracy: 0.6437 - val_loss: 0.6488 - val_accuracy: 0.6206
# Epoch 38/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6104 - accuracy: 0.6443
# Epoch 38: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6104 - accuracy: 0.6443 - val_loss: 0.6526 - val_accuracy: 0.6201
# Epoch 39/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6090 - accuracy: 0.6458
# Epoch 39: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6090 - accuracy: 0.6458 - val_loss: 0.6509 - val_accuracy: 0.6197
# Epoch 40/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6077 - accuracy: 0.6462
# Epoch 40: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6077 - accuracy: 0.6462 - val_loss: 0.6535 - val_accuracy: 0.6164
# Epoch 41/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6065 - accuracy: 0.6481
# Epoch 41: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6065 - accuracy: 0.6481 - val_loss: 0.6553 - val_accuracy: 0.6178
# Epoch 42/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6057 - accuracy: 0.6488
# Epoch 42: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6057 - accuracy: 0.6488 - val_loss: 0.6585 - val_accuracy: 0.6176
# Epoch 43/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6035 - accuracy: 0.6507
# Epoch 43: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6035 - accuracy: 0.6507 - val_loss: 0.6593 - val_accuracy: 0.6187
# Epoch 44/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6020 - accuracy: 0.6515
# Epoch 44: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6020 - accuracy: 0.6515 - val_loss: 0.6614 - val_accuracy: 0.6165
# Epoch 45/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6010 - accuracy: 0.6520
# Epoch 45: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.6010 - accuracy: 0.6520 - val_loss: 0.6632 - val_accuracy: 0.6170
# Epoch 46/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5990 - accuracy: 0.6538
# Epoch 46: val_loss did not improve from 0.63438
# 799/799 [==============================] - 239s 299ms/step - loss: 0.5990 - accuracy: 0.6538 - val_loss: 0.6648 - val_accuracy: 0.6168
# Training Time:  11022.416154384613 seconds

# %% [markdown]
# # Saving the model and training history

# %%
gru_model.save('GRU_Architecture_5_Features.h5')
np.save('GRU_history_5_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of GRU Network - 5 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of GRU Network - 5 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for GRU Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[-5.47251734e-01],
#         [-6.70051216e+00],
#         [-3.53210347e+00],
#         [-3.57554785e+00],
#         [-5.43491299e-04]],
#
#        [[ 1.51066078e+01],
#         [ 1.28901519e+01],
#         [ 9.38198263e+00],
#         [ 9.26921098e+00],
#         [ 4.60932318e+00]],
#
#        [[ 2.93699623e+00],
#         [ 4.82312356e-01],
#         [ 3.60238997e+00],
#         [ 1.55325021e+00],
#         [ 3.03395793e+00]],
#
#        ...,
#
#        [[-2.06647329e+00],
#         [-7.33303830e+00],
#         [-3.58371377e+00],
#         [-3.62013828e+00],
#         [-8.29692600e+00]],
#
#        [[ 2.22265807e+01],
#         [ 2.53946065e+01],
#         [ 1.44652072e+01],
#         [ 1.12923073e+01],
#         [ 2.03065733e+01]],
#
#        [[-1.10987164e+01],
#         [-3.76626649e+00],
#         [-3.26445408e-01],
#         [-1.70854942e+00],
#         [-1.16028270e+00]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = gru_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 59s 12ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = gru_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.62, Test loss: 0.63

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.65      0.64     77586
#            1       0.63      0.60      0.61     77704
#
#     accuracy                           0.62    155290
#    macro avg       0.63      0.62      0.62    155290
# weighted avg       0.63      0.62      0.62    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix GRU - 5 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.6249468735913453
# Precision: 0.6327992794366505
# Recall: 0.5967389066199938
# F1-score: 0.6142402967280435
# AUC-ROC: 0.6826460882951249

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['GRU - 5'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()

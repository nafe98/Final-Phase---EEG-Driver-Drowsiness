# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 8/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 8/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 8/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 8/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - GRU</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from tensorflow.keras.layers import GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for GRU

# %%
X_train_array = X_train  
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (8, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001

# %% [markdown]
# # 2. Define Architecture

# %%
gru_model = Sequential([
    
    GRU(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1),
    GRU(256, activation='relu'),
    Dropout(0.1),
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
gru_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 8, 512)            791040
#
#  dropout (Dropout)           (None, 8, 512)            0
#
#  gru_1 (GRU)                 (None, 256)               591360
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,382,657
# Trainable params: 1,382,657
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
gru_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Integrating Callbacks</h2>
#
# </div>

# %% [markdown]
# ## EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# ## Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/GRU_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = gru_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping], 
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6610 - accuracy: 0.5932
# Epoch 1: val_loss improved from inf to 0.64856, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 373s 460ms/step - loss: 0.6610 - accuracy: 0.5932 - val_loss: 0.6486 - val_accuracy: 0.6164
# Epoch 2/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6347 - accuracy: 0.6288
# Epoch 2: val_loss improved from 0.64856 to 0.62817, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 365s 456ms/step - loss: 0.6347 - accuracy: 0.6288 - val_loss: 0.6282 - val_accuracy: 0.6367
# Epoch 3/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6255 - accuracy: 0.6389
# Epoch 3: val_loss improved from 0.62817 to 0.62218, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 365s 456ms/step - loss: 0.6255 - accuracy: 0.6389 - val_loss: 0.6222 - val_accuracy: 0.6423
# Epoch 4/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6194 - accuracy: 0.6455
# Epoch 4: val_loss improved from 0.62218 to 0.61939, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 365s 457ms/step - loss: 0.6194 - accuracy: 0.6455 - val_loss: 0.6194 - val_accuracy: 0.6457
# Epoch 5/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6146 - accuracy: 0.6501
# Epoch 5: val_loss improved from 0.61939 to 0.61483, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 365s 457ms/step - loss: 0.6146 - accuracy: 0.6501 - val_loss: 0.6148 - val_accuracy: 0.6502
# Epoch 6/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6099 - accuracy: 0.6533
# Epoch 6: val_loss improved from 0.61483 to 0.61108, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 364s 456ms/step - loss: 0.6099 - accuracy: 0.6533 - val_loss: 0.6111 - val_accuracy: 0.6510
# Epoch 7/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6061 - accuracy: 0.6568
# Epoch 7: val_loss improved from 0.61108 to 0.60792, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 365s 456ms/step - loss: 0.6061 - accuracy: 0.6568 - val_loss: 0.6079 - val_accuracy: 0.6562
# Epoch 8/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6021 - accuracy: 0.6598
# Epoch 8: val_loss improved from 0.60792 to 0.60714, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 365s 457ms/step - loss: 0.6021 - accuracy: 0.6598 - val_loss: 0.6071 - val_accuracy: 0.6588
# Epoch 9/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5992 - accuracy: 0.6616
# Epoch 9: val_loss improved from 0.60714 to 0.60584, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 365s 457ms/step - loss: 0.5992 - accuracy: 0.6616 - val_loss: 0.6058 - val_accuracy: 0.6558
# Epoch 10/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5961 - accuracy: 0.6646
# Epoch 10: val_loss improved from 0.60584 to 0.60457, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 365s 457ms/step - loss: 0.5961 - accuracy: 0.6646 - val_loss: 0.6046 - val_accuracy: 0.6571
# Epoch 11/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5937 - accuracy: 0.6660
# Epoch 11: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 457ms/step - loss: 0.5937 - accuracy: 0.6660 - val_loss: 0.6063 - val_accuracy: 0.6573
# Epoch 12/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5903 - accuracy: 0.6688
# Epoch 12: val_loss did not improve from 0.60457
# 799/799 [==============================] - 364s 456ms/step - loss: 0.5903 - accuracy: 0.6688 - val_loss: 0.6056 - val_accuracy: 0.6574
# Epoch 13/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5884 - accuracy: 0.6705
# Epoch 13: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 457ms/step - loss: 0.5884 - accuracy: 0.6705 - val_loss: 0.6054 - val_accuracy: 0.6571
# Epoch 14/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5848 - accuracy: 0.6731
# Epoch 14: val_loss did not improve from 0.60457
# 799/799 [==============================] - 364s 456ms/step - loss: 0.5848 - accuracy: 0.6731 - val_loss: 0.6061 - val_accuracy: 0.6595
# Epoch 15/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5823 - accuracy: 0.6752
# Epoch 15: val_loss did not improve from 0.60457
# 799/799 [==============================] - 364s 456ms/step - loss: 0.5823 - accuracy: 0.6752 - val_loss: 0.6067 - val_accuracy: 0.6578
# Epoch 16/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5801 - accuracy: 0.6766
# Epoch 16: val_loss did not improve from 0.60457
# 799/799 [==============================] - 364s 456ms/step - loss: 0.5801 - accuracy: 0.6766 - val_loss: 0.6058 - val_accuracy: 0.6586
# Epoch 17/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5769 - accuracy: 0.6791
# Epoch 17: val_loss did not improve from 0.60457
# 799/799 [==============================] - 364s 456ms/step - loss: 0.5769 - accuracy: 0.6791 - val_loss: 0.6107 - val_accuracy: 0.6571
# Epoch 18/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5737 - accuracy: 0.6817
# Epoch 18: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 456ms/step - loss: 0.5737 - accuracy: 0.6817 - val_loss: 0.6107 - val_accuracy: 0.6575
# Epoch 19/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5703 - accuracy: 0.6840
# Epoch 19: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 457ms/step - loss: 0.5703 - accuracy: 0.6840 - val_loss: 0.6120 - val_accuracy: 0.6574
# Epoch 20/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5673 - accuracy: 0.6858
# Epoch 20: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 457ms/step - loss: 0.5673 - accuracy: 0.6858 - val_loss: 0.6128 - val_accuracy: 0.6574
# Epoch 21/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5633 - accuracy: 0.6891
# Epoch 21: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 457ms/step - loss: 0.5633 - accuracy: 0.6891 - val_loss: 0.6185 - val_accuracy: 0.6566
# Epoch 22/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5594 - accuracy: 0.6921
# Epoch 22: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 456ms/step - loss: 0.5594 - accuracy: 0.6921 - val_loss: 0.6210 - val_accuracy: 0.6534
# Epoch 23/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5559 - accuracy: 0.6939
# Epoch 23: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 457ms/step - loss: 0.5559 - accuracy: 0.6939 - val_loss: 0.6270 - val_accuracy: 0.6531
# Epoch 24/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5522 - accuracy: 0.6968
# Epoch 24: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 456ms/step - loss: 0.5522 - accuracy: 0.6968 - val_loss: 0.6256 - val_accuracy: 0.6543
# Epoch 25/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5480 - accuracy: 0.6989
# Epoch 25: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 456ms/step - loss: 0.5480 - accuracy: 0.6989 - val_loss: 0.6334 - val_accuracy: 0.6541
# Epoch 26/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5448 - accuracy: 0.7020
# Epoch 26: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 456ms/step - loss: 0.5448 - accuracy: 0.7020 - val_loss: 0.6375 - val_accuracy: 0.6525
# Epoch 27/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5401 - accuracy: 0.7056
# Epoch 27: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 457ms/step - loss: 0.5401 - accuracy: 0.7056 - val_loss: 0.6411 - val_accuracy: 0.6526
# Epoch 28/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5367 - accuracy: 0.7079
# Epoch 28: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 456ms/step - loss: 0.5367 - accuracy: 0.7079 - val_loss: 0.6417 - val_accuracy: 0.6510
# Epoch 29/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5325 - accuracy: 0.7110
# Epoch 29: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 457ms/step - loss: 0.5325 - accuracy: 0.7110 - val_loss: 0.6541 - val_accuracy: 0.6508
# Epoch 30/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5285 - accuracy: 0.7136
# Epoch 30: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 457ms/step - loss: 0.5285 - accuracy: 0.7136 - val_loss: 0.6558 - val_accuracy: 0.6502
# Epoch 31/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5273 - accuracy: 0.7149
# Epoch 31: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 457ms/step - loss: 0.5273 - accuracy: 0.7149 - val_loss: 0.6566 - val_accuracy: 0.6492
# Epoch 32/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5219 - accuracy: 0.7182
# Epoch 32: val_loss did not improve from 0.60457
# 799/799 [==============================] - 364s 456ms/step - loss: 0.5219 - accuracy: 0.7182 - val_loss: 0.6619 - val_accuracy: 0.6462
# Epoch 33/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5175 - accuracy: 0.7215
# Epoch 33: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 456ms/step - loss: 0.5175 - accuracy: 0.7215 - val_loss: 0.6665 - val_accuracy: 0.6479
# Epoch 34/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5138 - accuracy: 0.7241
# Epoch 34: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 457ms/step - loss: 0.5138 - accuracy: 0.7241 - val_loss: 0.6762 - val_accuracy: 0.6460
# Epoch 35/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5098 - accuracy: 0.7270
# Epoch 35: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 457ms/step - loss: 0.5098 - accuracy: 0.7270 - val_loss: 0.6818 - val_accuracy: 0.6462
# Epoch 36/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5047 - accuracy: 0.7308
# Epoch 36: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 457ms/step - loss: 0.5047 - accuracy: 0.7308 - val_loss: 0.6950 - val_accuracy: 0.6443
# Epoch 37/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5009 - accuracy: 0.7332
# Epoch 37: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 457ms/step - loss: 0.5009 - accuracy: 0.7332 - val_loss: 0.6911 - val_accuracy: 0.6439
# Epoch 38/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4969 - accuracy: 0.7357
# Epoch 38: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 457ms/step - loss: 0.4969 - accuracy: 0.7357 - val_loss: 0.7031 - val_accuracy: 0.6430
# Epoch 39/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4917 - accuracy: 0.7392
# Epoch 39: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 457ms/step - loss: 0.4917 - accuracy: 0.7392 - val_loss: 0.7127 - val_accuracy: 0.6418
# Epoch 40/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4899 - accuracy: 0.7413
# Epoch 40: val_loss did not improve from 0.60457
# 799/799 [==============================] - 365s 457ms/step - loss: 0.4899 - accuracy: 0.7413 - val_loss: 0.7123 - val_accuracy: 0.6398
# Training Time:  14600.679943323135 seconds

# %% [markdown]
# # Saving the model and training history

# %%
gru_model.save('GRU_Architecture_8_Features.h5')
np.save('GRU_history_8_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of GRU Network - 8 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of GRU Network - 8 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for LSTM Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[ -0.54725173],
#         [ -6.70051216],
#         [ -3.53210347],
#         ...,
#         [ -2.17029242],
#         [ -3.06658655],
#         [  5.46042838]],
#
#        [[ 15.10660785],
#         [ 12.89015194],
#         [  9.38198263],
#         ...,
#         [  9.04595295],
#         [  7.89297717],
#         [ 12.42090561]],
#
#        [[  2.93699623],
#         [  0.48231236],
#         [  3.60238997],
#         ...,
#         [  5.61697431],
#         [  0.97828094],
#         [  3.56758084]],
#
#        ...,
#
#        [[ -2.06647329],
#         [ -7.3330383 ],
#         [ -3.58371377],
#         ...,
#         [ -7.02601283],
#         [  1.43543209],
#         [  6.65836458]],
#
#        [[ 22.22658066],
#         [ 25.39460655],
#         [ 14.46520722],
#         ...,
#         [  7.47077347],
#         [ 13.26351064],
#         [ 16.49620515]],
#
#        [[-11.09871642],
#         [ -3.76626649],
#         [ -0.32644541],
#         ...,
#         [ -3.22621688],
#         [  0.13967151],
#         [  1.39151142]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = gru_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 80s 16ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = gru_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.66, Test loss: 0.60

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.65      0.66     77586
#            1       0.66      0.66      0.66     77704
#
#     accuracy                           0.66    155290
#    macro avg       0.66      0.66      0.66    155290
# weighted avg       0.66      0.66      0.66    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix GRU - 8 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.6572606091828193
# Precision: 0.6559792027729636
# Recall: 0.6624626788839699
# F1-score: 0.6592049994877573
# AUC-ROC: 0.7258505282921898

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['GRU - 8'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()

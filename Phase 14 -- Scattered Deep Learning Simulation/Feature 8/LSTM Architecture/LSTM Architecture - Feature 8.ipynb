# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 8/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 8/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 8/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 8/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - LSTM</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
from keras.layers import LSTM
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for LSTM

# %%
X_train_array = X_train  
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (8, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# # 2. Define Architecture

# %%
lstm_model = Sequential([
    
    LSTM(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1), 
    LSTM(256, activation='relu'),
    Dropout(0.1),  
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 8, 512)            1052672
#
#  dropout (Dropout)           (None, 8, 512)            0
#
#  lstm_1 (LSTM)               (None, 256)               787456
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,840,385
# Trainable params: 1,840,385
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
lstm_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = lstm_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[early_stopping], 
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - 352s 432ms/step - loss: 0.6656 - accuracy: 0.5857 - val_loss: 0.6588 - val_accuracy: 0.6001
# Epoch 2/500
# 799/799 [==============================] - 345s 431ms/step - loss: 0.6446 - accuracy: 0.6168 - val_loss: 0.6346 - val_accuracy: 0.6278
# Epoch 3/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.6289 - accuracy: 0.6352 - val_loss: 0.6248 - val_accuracy: 0.6392
# Epoch 4/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.6221 - accuracy: 0.6421 - val_loss: 0.6215 - val_accuracy: 0.6436
# Epoch 5/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.6169 - accuracy: 0.6465 - val_loss: 0.6188 - val_accuracy: 0.6481
# Epoch 6/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.6127 - accuracy: 0.6504 - val_loss: 0.6142 - val_accuracy: 0.6510
# Epoch 7/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.6085 - accuracy: 0.6546 - val_loss: 0.6124 - val_accuracy: 0.6511
# Epoch 8/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.6046 - accuracy: 0.6578 - val_loss: 0.6103 - val_accuracy: 0.6560
# Epoch 9/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.6015 - accuracy: 0.6604 - val_loss: 0.6093 - val_accuracy: 0.6564
# Epoch 10/500
# 799/799 [==============================] - 345s 431ms/step - loss: 0.5983 - accuracy: 0.6634 - val_loss: 0.6100 - val_accuracy: 0.6568
# Epoch 11/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5950 - accuracy: 0.6657 - val_loss: 0.6090 - val_accuracy: 0.6574
# Epoch 12/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5923 - accuracy: 0.6669 - val_loss: 0.6075 - val_accuracy: 0.6586
# Epoch 13/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5888 - accuracy: 0.6706 - val_loss: 0.6102 - val_accuracy: 0.6577
# Epoch 14/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5851 - accuracy: 0.6729 - val_loss: 0.6092 - val_accuracy: 0.6579
# Epoch 15/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5823 - accuracy: 0.6748 - val_loss: 0.6086 - val_accuracy: 0.6591
# Epoch 16/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5795 - accuracy: 0.6770 - val_loss: 0.6110 - val_accuracy: 0.6588
# Epoch 17/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5761 - accuracy: 0.6791 - val_loss: 0.6145 - val_accuracy: 0.6586
# Epoch 18/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5716 - accuracy: 0.6824 - val_loss: 0.6153 - val_accuracy: 0.6585
# Epoch 19/500
# 799/799 [==============================] - 345s 431ms/step - loss: 0.5679 - accuracy: 0.6846 - val_loss: 0.6184 - val_accuracy: 0.6567
# Epoch 20/500
# 799/799 [==============================] - 345s 431ms/step - loss: 0.5640 - accuracy: 0.6873 - val_loss: 0.6229 - val_accuracy: 0.6574
# Epoch 21/500
# 799/799 [==============================] - 345s 431ms/step - loss: 0.5613 - accuracy: 0.6891 - val_loss: 0.6263 - val_accuracy: 0.6551
# Epoch 22/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5602 - accuracy: 0.6907 - val_loss: 0.6261 - val_accuracy: 0.6559
# Epoch 23/500
# 799/799 [==============================] - 345s 431ms/step - loss: 0.5542 - accuracy: 0.6947 - val_loss: 0.6336 - val_accuracy: 0.6537
# Epoch 24/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5479 - accuracy: 0.6986 - val_loss: 0.6418 - val_accuracy: 0.6538
# Epoch 25/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5429 - accuracy: 0.7025 - val_loss: 0.6447 - val_accuracy: 0.6528
# Epoch 26/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5397 - accuracy: 0.7048 - val_loss: 0.6450 - val_accuracy: 0.6549
# Epoch 27/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5359 - accuracy: 0.7076 - val_loss: 0.6511 - val_accuracy: 0.6533
# Epoch 28/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5333 - accuracy: 0.7096 - val_loss: 0.6571 - val_accuracy: 0.6502
# Epoch 29/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5271 - accuracy: 0.7131 - val_loss: 0.6647 - val_accuracy: 0.6508
# Epoch 30/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5223 - accuracy: 0.7170 - val_loss: 0.6779 - val_accuracy: 0.6491
# Epoch 31/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5143 - accuracy: 0.7213 - val_loss: 0.6854 - val_accuracy: 0.6470
# Epoch 32/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5101 - accuracy: 0.7252 - val_loss: 0.6857 - val_accuracy: 0.6461
# Epoch 33/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5075 - accuracy: 0.7275 - val_loss: 0.6947 - val_accuracy: 0.6475
# Epoch 34/500
# 799/799 [==============================] - 345s 431ms/step - loss: 0.5169 - accuracy: 0.7239 - val_loss: 0.6825 - val_accuracy: 0.6430
# Epoch 35/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.5065 - accuracy: 0.7292 - val_loss: 0.6996 - val_accuracy: 0.6437
# Epoch 36/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.4939 - accuracy: 0.7367 - val_loss: 0.7217 - val_accuracy: 0.6422
# Epoch 37/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.4964 - accuracy: 0.7368 - val_loss: 0.7139 - val_accuracy: 0.6409
# Epoch 38/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.4870 - accuracy: 0.7422 - val_loss: 0.7337 - val_accuracy: 0.6399
# Epoch 39/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.4873 - accuracy: 0.7423 - val_loss: 0.7404 - val_accuracy: 0.6340
# Epoch 40/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.4789 - accuracy: 0.7473 - val_loss: 0.7504 - val_accuracy: 0.6373
# Epoch 41/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.4715 - accuracy: 0.7523 - val_loss: 0.7453 - val_accuracy: 0.6380
# Epoch 42/500
# 799/799 [==============================] - 344s 431ms/step - loss: 0.4892 - accuracy: 0.7448 - val_loss: 0.7264 - val_accuracy: 0.6366
# Training Time:  14478.211450338364 seconds
# Epoch 169/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.2236 - accuracy: 0.9093 - val_loss: 0.2991 - val_accuracy: 0.8778
# Epoch 170/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.2149 - accuracy: 0.9119 - val_loss: 0.3086 - val_accuracy: 0.8750
# Epoch 171/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1998 - accuracy: 0.9132 - val_loss: 0.2951 - val_accuracy: 0.8799
# Epoch 172/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1963 - accuracy: 0.9145 - val_loss: 0.2963 - val_accuracy: 0.8793
# Epoch 173/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1937 - accuracy: 0.9150 - val_loss: 0.2983 - val_accuracy: 0.8796
# Epoch 174/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1903 - accuracy: 0.9164 - val_loss: 0.2913 - val_accuracy: 0.8816
# Epoch 175/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1911 - accuracy: 0.9163 - val_loss: 0.2920 - val_accuracy: 0.8823
# Epoch 176/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.1896 - accuracy: 0.9170 - val_loss: 0.2981 - val_accuracy: 0.8809
# Epoch 177/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1900 - accuracy: 0.9169 - val_loss: 0.2995 - val_accuracy: 0.8801
# Epoch 178/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1926 - accuracy: 0.9161 - val_loss: 0.2909 - val_accuracy: 0.8814
# Epoch 179/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1893 - accuracy: 0.9171 - val_loss: 0.2903 - val_accuracy: 0.8836
# Epoch 180/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1890 - accuracy: 0.9176 - val_loss: 0.2945 - val_accuracy: 0.8804
# Epoch 181/500
# 799/799 [==============================] - 19s 23ms/step - loss: 0.1863 - accuracy: 0.9182 - val_loss: 0.2940 - val_accuracy: 0.8822
# Epoch 182/500
# 799/799 [==============================] - 19s 23ms/step - loss: 0.1854 - accuracy: 0.9193 - val_loss: 0.2916 - val_accuracy: 0.8834
# Epoch 183/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.1882 - accuracy: 0.9184 - val_loss: 0.2903 - val_accuracy: 0.8833
# Epoch 184/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.1861 - accuracy: 0.9190 - val_loss: 0.2956 - val_accuracy: 0.8821
# Epoch 185/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1893 - accuracy: 0.9179 - val_loss: 0.2924 - val_accuracy: 0.8835
# Epoch 186/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1838 - accuracy: 0.9199 - val_loss: 0.2878 - val_accuracy: 0.8853
# Epoch 187/500
# 799/799 [==============================] - 18s 23ms/step - loss: 0.1812 - accuracy: 0.9208 - val_loss: 0.2940 - val_accuracy: 0.8836
# Epoch 188/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1869 - accuracy: 0.9198 - val_loss: 0.2979 - val_accuracy: 0.8839
# Epoch 189/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1834 - accuracy: 0.9208 - val_loss: 0.2930 - val_accuracy: 0.8846
# Epoch 190/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1828 - accuracy: 0.9208 - val_loss: 0.2951 - val_accuracy: 0.8848
# Epoch 191/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1797 - accuracy: 0.9222 - val_loss: 0.2952 - val_accuracy: 0.8854
# Epoch 192/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1780 - accuracy: 0.9225 - val_loss: 0.2902 - val_accuracy: 0.8839
# Epoch 193/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1794 - accuracy: 0.9224 - val_loss: 0.2954 - val_accuracy: 0.8856
# Epoch 194/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1793 - accuracy: 0.9225 - val_loss: 0.2906 - val_accuracy: 0.8865
# Epoch 195/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1768 - accuracy: 0.9229 - val_loss: 0.2956 - val_accuracy: 0.8845
# Epoch 196/500
# 799/799 [==============================] - 20s 24ms/step - loss: 0.1769 - accuracy: 0.9230 - val_loss: 0.2912 - val_accuracy: 0.8844
# Epoch 197/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1763 - accuracy: 0.9237 - val_loss: 0.2936 - val_accuracy: 0.8861
# Epoch 198/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1786 - accuracy: 0.9231 - val_loss: 0.2919 - val_accuracy: 0.8853
# Epoch 199/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1774 - accuracy: 0.9237 - val_loss: 0.2957 - val_accuracy: 0.8851
# Epoch 200/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1752 - accuracy: 0.9244 - val_loss: 0.2915 - val_accuracy: 0.8866
# Epoch 201/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1738 - accuracy: 0.9248 - val_loss: 0.2927 - val_accuracy: 0.8861
# Epoch 202/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1747 - accuracy: 0.9247 - val_loss: 0.3182 - val_accuracy: 0.8753
# Epoch 203/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1775 - accuracy: 0.9237 - val_loss: 0.2931 - val_accuracy: 0.8860
# Epoch 204/500
# 799/799 [==============================] - 20s 26ms/step - loss: 0.1723 - accuracy: 0.9253 - val_loss: 0.2937 - val_accuracy: 0.8868
# Epoch 205/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1786 - accuracy: 0.9234 - val_loss: 0.2929 - val_accuracy: 0.8866
# Epoch 206/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1742 - accuracy: 0.9256 - val_loss: 0.2946 - val_accuracy: 0.8869
# Epoch 207/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1756 - accuracy: 0.9249 - val_loss: 0.2977 - val_accuracy: 0.8857
# Epoch 208/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1711 - accuracy: 0.9267 - val_loss: 0.2894 - val_accuracy: 0.8877
# Epoch 209/500
# 799/799 [==============================] - 21s 26ms/step - loss: 0.1708 - accuracy: 0.9267 - val_loss: 0.2937 - val_accuracy: 0.8863
# Epoch 210/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1713 - accuracy: 0.9264 - val_loss: 0.2966 - val_accuracy: 0.8860
# Epoch 211/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1714 - accuracy: 0.9263 - val_loss: 0.2967 - val_accuracy: 0.8865
# Epoch 212/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1699 - accuracy: 0.9269 - val_loss: 0.2942 - val_accuracy: 0.8876
# Epoch 213/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1672 - accuracy: 0.9282 - val_loss: 0.2923 - val_accuracy: 0.8882
# Epoch 214/500
# 799/799 [==============================] - 19s 24ms/step - loss: 0.1701 - accuracy: 0.9270 - val_loss: 0.2963 - val_accuracy: 0.8871
# Epoch 215/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1683 - accuracy: 0.9277 - val_loss: 0.2918 - val_accuracy: 0.8879
# Epoch 216/500
# 799/799 [==============================] - 20s 25ms/step - loss: 0.1680 - accuracy: 0.9278 - val_loss: 0.2916 - val_accuracy: 0.8880
# Training Time:  4259.20539855957 seconds

# %% [markdown]
# # Saving the model and training history

# %%
lstm_model.save('LSTM_Architecture_8_Features.h5')
np.save('LSTM_history_8_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of LSTM Neural Network - 8 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of LSTM Neural Network - 8 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for LSTM Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[ -0.54725173],
#         [ -6.70051216],
#         [ -3.53210347],
#         ...,
#         [ -2.17029242],
#         [ -3.06658655],
#         [  5.46042838]],
#
#        [[ 15.10660785],
#         [ 12.89015194],
#         [  9.38198263],
#         ...,
#         [  9.04595295],
#         [  7.89297717],
#         [ 12.42090561]],
#
#        [[  2.93699623],
#         [  0.48231236],
#         [  3.60238997],
#         ...,
#         [  5.61697431],
#         [  0.97828094],
#         [  3.56758084]],
#
#        ...,
#
#        [[ -2.06647329],
#         [ -7.3330383 ],
#         [ -3.58371377],
#         ...,
#         [ -7.02601283],
#         [  1.43543209],
#         [  6.65836458]],
#
#        [[ 22.22658066],
#         [ 25.39460655],
#         [ 14.46520722],
#         ...,
#         [  7.47077347],
#         [ 13.26351064],
#         [ 16.49620515]],
#
#        [[-11.09871642],
#         [ -3.76626649],
#         [ -0.32644541],
#         ...,
#         [ -3.22621688],
#         [  0.13967151],
#         [  1.39151142]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = lstm_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 75s 15ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = lstm_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.66, Test loss: 0.61

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.63      0.65     77586
#            1       0.65      0.68      0.66     77704
#
#     accuracy                           0.66    155290
#    macro avg       0.66      0.66      0.66    155290
# weighted avg       0.66      0.66      0.66    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix LSTM - 8 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.6565522570674223
# Precision: 0.6499803062379991
# Recall: 0.6795917842067333
# F1-score: 0.6644563001736417
# AUC-ROC: 0.7245980043297069

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['LSTM - 8'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()

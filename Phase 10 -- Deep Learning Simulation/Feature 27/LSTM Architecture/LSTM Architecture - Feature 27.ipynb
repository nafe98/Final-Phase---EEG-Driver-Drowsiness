# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 27/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 27/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 27/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 27/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - LSTM</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
from keras.layers import LSTM
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for LSTM

# %%
X_train_array = X_train  
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (27, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001

# %% [markdown]
# # 2. Define Architecture

# %%
lstm_model = Sequential([
    
    LSTM(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1), 
    LSTM(256, activation='relu'),
    Dropout(0.1),  
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 27, 512)           1052672
#
#  dropout (Dropout)           (None, 27, 512)           0
#
#  lstm_1 (LSTM)               (None, 256)               787456
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,840,385
# Trainable params: 1,840,385
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
lstm_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# ## Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/LSTM_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = lstm_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping],  
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - ETA: 0s - loss: 1.3451 - accuracy: 0.6127
# Epoch 1: val_loss improved from inf to 0.64131, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 1108s 1s/step - loss: 1.3451 - accuracy: 0.6127 - val_loss: 0.6413 - val_accuracy: 0.6288
# Epoch 2/500
# 799/799 [==============================] - ETA: 0s - loss: 0.9704 - accuracy: 0.6248
# Epoch 2: val_loss did not improve from 0.64131
# 799/799 [==============================] - 1103s 1s/step - loss: 0.9704 - accuracy: 0.6248 - val_loss: 0.6421 - val_accuracy: 0.6319
# Epoch 3/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6324 - accuracy: 0.6382
# Epoch 3: val_loss improved from 0.64131 to 0.62418, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 1104s 1s/step - loss: 0.6324 - accuracy: 0.6382 - val_loss: 0.6242 - val_accuracy: 0.6452
# Epoch 4/500
# 799/799 [==============================] - ETA: 0s - loss: 36.3666 - accuracy: 0.6368
# Epoch 4: val_loss did not improve from 0.62418
# 799/799 [==============================] - 1104s 1s/step - loss: 36.3666 - accuracy: 0.6368 - val_loss: 21.1037 - val_accuracy: 0.5428
# Epoch 5/500
# 799/799 [==============================] - ETA: 0s - loss: 1.6545 - accuracy: 0.5866
# Epoch 5: val_loss did not improve from 0.62418
# 799/799 [==============================] - 1104s 1s/step - loss: 1.6545 - accuracy: 0.5866 - val_loss: 0.6642 - val_accuracy: 0.6074
# Epoch 6/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6540 - accuracy: 0.6181
# Epoch 6: val_loss did not improve from 0.62418
# 799/799 [==============================] - 1104s 1s/step - loss: 0.6540 - accuracy: 0.6181 - val_loss: 0.6556 - val_accuracy: 0.6203
# Epoch 7/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6465 - accuracy: 0.6262
# Epoch 7: val_loss did not improve from 0.62418
# 799/799 [==============================] - 1104s 1s/step - loss: 0.6465 - accuracy: 0.6262 - val_loss: 0.6388 - val_accuracy: 0.6311
# Epoch 8/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6400 - accuracy: 0.6332
# Epoch 8: val_loss did not improve from 0.62418
# 799/799 [==============================] - 1104s 1s/step - loss: 0.6400 - accuracy: 0.6332 - val_loss: 0.6362 - val_accuracy: 0.6351
# Epoch 9/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6372 - accuracy: 0.6376
# Epoch 9: val_loss did not improve from 0.62418
# 799/799 [==============================] - 1104s 1s/step - loss: 0.6372 - accuracy: 0.6376 - val_loss: 0.6325 - val_accuracy: 0.6378
# Epoch 10/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6375 - accuracy: 0.6422
# Epoch 10: val_loss improved from 0.62418 to 0.62368, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 1104s 1s/step - loss: 0.6375 - accuracy: 0.6422 - val_loss: 0.6237 - val_accuracy: 0.6447
# Epoch 11/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6398 - accuracy: 0.6398
# Epoch 11: val_loss did not improve from 0.62368
# 799/799 [==============================] - 1103s 1s/step - loss: 0.6398 - accuracy: 0.6398 - val_loss: 0.6270 - val_accuracy: 0.6442
# Epoch 12/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6223 - accuracy: 0.6486
# Epoch 12: val_loss improved from 0.62368 to 0.61261, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 1103s 1s/step - loss: 0.6223 - accuracy: 0.6486 - val_loss: 0.6126 - val_accuracy: 0.6554
# Epoch 13/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6263 - accuracy: 0.6498
# Epoch 13: val_loss did not improve from 0.61261
# 799/799 [==============================] - 1104s 1s/step - loss: 0.6263 - accuracy: 0.6498 - val_loss: 0.6255 - val_accuracy: 0.6488
# Epoch 14/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6119 - accuracy: 0.6591
# Epoch 14: val_loss improved from 0.61261 to 0.60092, saving model to /Model Checkpoints\LSTM_Model_Checkpoint.h5
# 799/799 [==============================] - 1104s 1s/step - loss: 0.6119 - accuracy: 0.6591 - val_loss: 0.6009 - val_accuracy: 0.6685
# Epoch 15/500
# 799/799 [==============================] - ETA: 0s - loss: 2220.6143 - accuracy: 0.5636
# Epoch 15: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 2220.6143 - accuracy: 0.5636 - val_loss: 1.1172 - val_accuracy: 0.5480
# Epoch 16/500
# 799/799 [==============================] - ETA: 0s - loss: 1.9853 - accuracy: 0.5574
# Epoch 16: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 1.9853 - accuracy: 0.5574 - val_loss: 0.7172 - val_accuracy: 0.5878
# Epoch 17/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7389 - accuracy: 0.5752
# Epoch 17: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1104s 1s/step - loss: 0.7389 - accuracy: 0.5752 - val_loss: 0.6709 - val_accuracy: 0.5980
# Epoch 18/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6847 - accuracy: 0.6008
# Epoch 18: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 0.6847 - accuracy: 0.6008 - val_loss: 0.6544 - val_accuracy: 0.6171
# Epoch 19/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6749 - accuracy: 0.6126
# Epoch 19: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 0.6749 - accuracy: 0.6126 - val_loss: 0.6597 - val_accuracy: 0.6061
# Epoch 20/500
# 799/799 [==============================] - ETA: 0s - loss: 3.5712 - accuracy: 0.5736
# Epoch 20: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 3.5712 - accuracy: 0.5736 - val_loss: 0.6853 - val_accuracy: 0.5644
# Epoch 21/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7086 - accuracy: 0.5767
# Epoch 21: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 0.7086 - accuracy: 0.5767 - val_loss: 0.6610 - val_accuracy: 0.6075
# Epoch 22/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7023 - accuracy: 0.5952
# Epoch 22: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 0.7023 - accuracy: 0.5952 - val_loss: 0.6961 - val_accuracy: 0.5924
# Epoch 23/500
# 799/799 [==============================] - ETA: 0s - loss: 7360.0249 - accuracy: 0.5702
# Epoch 23: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 7360.0249 - accuracy: 0.5702 - val_loss: 14.7978 - val_accuracy: 0.5467
# Epoch 24/500
# 799/799 [==============================] - ETA: 0s - loss: 7.8836 - accuracy: 0.5375
# Epoch 24: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 7.8836 - accuracy: 0.5375 - val_loss: 0.8828 - val_accuracy: 0.5487
# Epoch 25/500
# 799/799 [==============================] - ETA: 0s - loss: 2.4238 - accuracy: 0.5620
# Epoch 25: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 2.4238 - accuracy: 0.5620 - val_loss: 0.9998 - val_accuracy: 0.6039
# Epoch 26/500
# 799/799 [==============================] - ETA: 0s - loss: 1.3954 - accuracy: 0.5767
# Epoch 26: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 1.3954 - accuracy: 0.5767 - val_loss: 1.0112 - val_accuracy: 0.6092
# Epoch 27/500
# 799/799 [==============================] - ETA: 0s - loss: 1.1620 - accuracy: 0.5856
# Epoch 27: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 1.1620 - accuracy: 0.5856 - val_loss: 0.7873 - val_accuracy: 0.5716
# Epoch 28/500
# 799/799 [==============================] - ETA: 0s - loss: 0.9413 - accuracy: 0.5817
# Epoch 28: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 0.9413 - accuracy: 0.5817 - val_loss: 0.6817 - val_accuracy: 0.5996
# Epoch 29/500
# 799/799 [==============================] - ETA: 0s - loss: 0.8216 - accuracy: 0.5924
# Epoch 29: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 0.8216 - accuracy: 0.5924 - val_loss: 0.7352 - val_accuracy: 0.6142
# Epoch 30/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7838 - accuracy: 0.5965
# Epoch 30: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 0.7838 - accuracy: 0.5965 - val_loss: 0.7111 - val_accuracy: 0.5748
# Epoch 31/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7410 - accuracy: 0.6004
# Epoch 31: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 0.7410 - accuracy: 0.6004 - val_loss: 0.8294 - val_accuracy: 0.5691
# Epoch 32/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6913 - accuracy: 0.6100
# Epoch 32: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 0.6913 - accuracy: 0.6100 - val_loss: 0.6519 - val_accuracy: 0.6255
# Epoch 33/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6638 - accuracy: 0.6180
# Epoch 33: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 0.6638 - accuracy: 0.6180 - val_loss: 0.6421 - val_accuracy: 0.6307
# Epoch 34/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7212 - accuracy: 0.6051
# Epoch 34: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 0.7212 - accuracy: 0.6051 - val_loss: 0.6578 - val_accuracy: 0.6225
# Epoch 35/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6744 - accuracy: 0.6128
# Epoch 35: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 0.6744 - accuracy: 0.6128 - val_loss: 0.6438 - val_accuracy: 0.6295
# Epoch 36/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6721 - accuracy: 0.6050
# Epoch 36: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1104s 1s/step - loss: 0.6721 - accuracy: 0.6050 - val_loss: 0.6514 - val_accuracy: 0.6193
# Epoch 37/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6900 - accuracy: 0.6157
# Epoch 37: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 0.6900 - accuracy: 0.6157 - val_loss: 0.6460 - val_accuracy: 0.6247
# Epoch 38/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6586 - accuracy: 0.6188
# Epoch 38: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 0.6586 - accuracy: 0.6188 - val_loss: 0.6460 - val_accuracy: 0.6238
# Epoch 39/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6477 - accuracy: 0.6288
# Epoch 39: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1102s 1s/step - loss: 0.6477 - accuracy: 0.6288 - val_loss: 0.6451 - val_accuracy: 0.6243
# Epoch 40/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6799 - accuracy: 0.6161
# Epoch 40: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1102s 1s/step - loss: 0.6799 - accuracy: 0.6161 - val_loss: 0.6457 - val_accuracy: 0.6249
# Epoch 41/500
# 799/799 [==============================] - ETA: 0s - loss: 2.8340 - accuracy: 0.6022
# Epoch 41: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 2.8340 - accuracy: 0.6022 - val_loss: 0.8332 - val_accuracy: 0.4923
# Epoch 42/500
# 799/799 [==============================] - ETA: 0s - loss: 0.9184 - accuracy: 0.5124
# Epoch 42: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1104s 1s/step - loss: 0.9184 - accuracy: 0.5124 - val_loss: 0.7075 - val_accuracy: 0.5353
# Epoch 43/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7620 - accuracy: 0.5301
# Epoch 43: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 0.7620 - accuracy: 0.5301 - val_loss: 0.6843 - val_accuracy: 0.5627
# Epoch 44/500
# 799/799 [==============================] - ETA: 0s - loss: 0.9006 - accuracy: 0.5460
# Epoch 44: val_loss did not improve from 0.60092
# 799/799 [==============================] - 1103s 1s/step - loss: 0.9006 - accuracy: 0.5460 - val_loss: 0.6992 - val_accuracy: 0.5347
# Training Time:  48549.21490907669 seconds

# %% [markdown]
# # Saving the model and training history

# %%
lstm_model.save('LSTM_Architecture_27_Features.h5')
np.save('LSTM_history_27_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of LSTM Neural Network - 27 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of LSTM Neural Network - 27 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for LSTM Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[ 0.46349357],
#         [ 0.36358773],
#         [ 3.37428511],
#         ...,
#         [ 0.54589363],
#         [ 0.76277015],
#         [-0.66724627]],
#
#        [[-3.12902325],
#         [-2.41096786],
#         [-4.83420457],
#         ...,
#         [-0.9701542 ],
#         [-2.61791719],
#         [-2.31896119]],
#
#        [[ 1.56338732],
#         [ 1.49249955],
#         [ 1.91877559],
#         ...,
#         [ 1.24833052],
#         [ 1.42932367],
#         [ 1.35848926]],
#
#        ...,
#
#        [[ 0.69592067],
#         [ 0.84838968],
#         [-0.60272074],
#         ...,
#         [ 0.65452093],
#         [ 1.35513171],
#         [ 1.22326088]],
#
#        [[ 2.17107007],
#         [ 2.96016373],
#         [ 3.46610892],
#         ...,
#         [ 2.15426389],
#         [ 2.52736704],
#         [ 1.96490661]],
#
#        [[ 0.16525652],
#         [-0.05828783],
#         [-0.23818711],
#         ...,
#         [-0.28802406],
#         [ 0.25460157],
#         [ 1.08541927]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = lstm_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 219s 45ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = lstm_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.67, Test loss: 0.60

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.71      0.68     77676
#            1       0.69      0.63      0.66     77614
#
#     accuracy                           0.67    155290
#    macro avg       0.67      0.67      0.67    155290
# weighted avg       0.67      0.67      0.67    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix LSTM - 27 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.6714147723613884
# Precision: 0.6868499465902064
# Recall: 0.6296286752390032
# F1-score: 0.6569957381589384
# AUC-ROC: 0.734285775564518

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['LSTM - 27'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()

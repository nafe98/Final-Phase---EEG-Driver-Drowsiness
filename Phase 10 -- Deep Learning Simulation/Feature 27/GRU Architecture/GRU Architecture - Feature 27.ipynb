# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 27/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 27/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 27/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 27/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - GRU</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from tensorflow.keras.layers import GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# ### Reshaping X_train for GRU

# %%
X_train_array = X_train  
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
input_shape = (X_train_reshaped.shape[1], X_train_reshaped.shape[2])

# %%
input_shape
# Out:
# (27, 1)

# %% [markdown]
# # 1. Network Initialization

# %%
batch_size = 700  
epochs = 500  
learning_rate = 0.001

# %% [markdown]
# # 2. Define Architecture

# %%
gru_model = Sequential([
    
    GRU(512, input_shape=input_shape, activation='relu', return_sequences=True),
    Dropout(0.1),
    GRU(256, activation='relu'),
    Dropout(0.1),
    Dense(1, activation='sigmoid')

])
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
gru_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 27, 512)           791040
#
#  dropout (Dropout)           (None, 27, 512)           0
#
#  gru_1 (GRU)                 (None, 256)               591360
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,382,657
# Trainable params: 1,382,657
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
gru_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Integrating Callbacks</h2>
#
# </div>

# %% [markdown]
# ## EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# ## Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/GRU_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")
# Out:
# Loading model from checkpoint...
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = gru_model.fit(X_train_reshaped, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping], 
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6399 - accuracy: 0.6265
# Epoch 1: val_loss improved from inf to 0.62456, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 1166s 1s/step - loss: 0.6399 - accuracy: 0.6265 - val_loss: 0.6246 - val_accuracy: 0.6400
# Epoch 2/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5928 - accuracy: 0.6706
# Epoch 2: val_loss improved from 0.62456 to 0.56013, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 1158s 1s/step - loss: 0.5928 - accuracy: 0.6706 - val_loss: 0.5601 - val_accuracy: 0.6947
# Epoch 3/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5238 - accuracy: 0.7230
# Epoch 3: val_loss improved from 0.56013 to 0.48915, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 1157s 1s/step - loss: 0.5238 - accuracy: 0.7230 - val_loss: 0.4891 - val_accuracy: 0.7483
# Epoch 4/500
# 799/799 [==============================] - ETA: 0s - loss: 0.4294 - accuracy: 0.7870
# Epoch 4: val_loss improved from 0.48915 to 0.39721, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 1157s 1s/step - loss: 0.4294 - accuracy: 0.7870 - val_loss: 0.3972 - val_accuracy: 0.8084
# Epoch 5/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3391 - accuracy: 0.8413
# Epoch 5: val_loss improved from 0.39721 to 0.29624, saving model to /Model Checkpoints\GRU_Model_Checkpoint.h5
# 799/799 [==============================] - 1194s 1s/step - loss: 0.3391 - accuracy: 0.8413 - val_loss: 0.2962 - val_accuracy: 0.8664
# Epoch 6/500
# 799/799 [==============================] - ETA: 0s - loss: 0.3299 - accuracy: 0.8432
# Epoch 6: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1203s 2s/step - loss: 0.3299 - accuracy: 0.8432 - val_loss: 0.6326 - val_accuracy: 0.6427
# Epoch 7/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6590 - accuracy: 0.6167
# Epoch 7: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1158s 1s/step - loss: 0.6590 - accuracy: 0.6167 - val_loss: 0.6423 - val_accuracy: 0.6279
# Epoch 8/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6392 - accuracy: 0.6329
# Epoch 8: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1158s 1s/step - loss: 0.6392 - accuracy: 0.6329 - val_loss: 0.6248 - val_accuracy: 0.6453
# Epoch 9/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6426 - accuracy: 0.6340
# Epoch 9: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1158s 1s/step - loss: 0.6426 - accuracy: 0.6340 - val_loss: 0.6494 - val_accuracy: 0.6215
# Epoch 10/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6485 - accuracy: 0.6237
# Epoch 10: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1158s 1s/step - loss: 0.6485 - accuracy: 0.6237 - val_loss: 0.6346 - val_accuracy: 0.6383
# Epoch 11/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6317 - accuracy: 0.6385
# Epoch 11: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1158s 1s/step - loss: 0.6317 - accuracy: 0.6385 - val_loss: 0.6172 - val_accuracy: 0.6517
# Epoch 12/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6163 - accuracy: 0.6518
# Epoch 12: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1158s 1s/step - loss: 0.6163 - accuracy: 0.6518 - val_loss: 0.6015 - val_accuracy: 0.6665
# Epoch 13/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6012 - accuracy: 0.6670
# Epoch 13: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1158s 1s/step - loss: 0.6012 - accuracy: 0.6670 - val_loss: 0.5837 - val_accuracy: 0.6801
# Epoch 14/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5877 - accuracy: 0.6792
# Epoch 14: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1157s 1s/step - loss: 0.5877 - accuracy: 0.6792 - val_loss: 0.5714 - val_accuracy: 0.6921
# Epoch 15/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5752 - accuracy: 0.6891
# Epoch 15: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1158s 1s/step - loss: 0.5752 - accuracy: 0.6891 - val_loss: 0.5564 - val_accuracy: 0.7037
# Epoch 16/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5814 - accuracy: 0.6854
# Epoch 16: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1157s 1s/step - loss: 0.5814 - accuracy: 0.6854 - val_loss: 0.5729 - val_accuracy: 0.6920
# Epoch 17/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6010 - accuracy: 0.6694
# Epoch 17: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1157s 1s/step - loss: 0.6010 - accuracy: 0.6694 - val_loss: 0.5989 - val_accuracy: 0.6663
# Epoch 18/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5933 - accuracy: 0.6744
# Epoch 18: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1157s 1s/step - loss: 0.5933 - accuracy: 0.6744 - val_loss: 0.5682 - val_accuracy: 0.6940
# Epoch 19/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5683 - accuracy: 0.6947
# Epoch 19: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1157s 1s/step - loss: 0.5683 - accuracy: 0.6947 - val_loss: 0.5451 - val_accuracy: 0.7154
# Epoch 20/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5467 - accuracy: 0.7125
# Epoch 20: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1158s 1s/step - loss: 0.5467 - accuracy: 0.7125 - val_loss: 0.5273 - val_accuracy: 0.7258
# Epoch 21/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5374 - accuracy: 0.7196
# Epoch 21: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1158s 1s/step - loss: 0.5374 - accuracy: 0.7196 - val_loss: 0.5107 - val_accuracy: 0.7400
# Epoch 22/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5550 - accuracy: 0.7078
# Epoch 22: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1158s 1s/step - loss: 0.5550 - accuracy: 0.7078 - val_loss: 0.5904 - val_accuracy: 0.6767
# Epoch 23/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5788 - accuracy: 0.6887
# Epoch 23: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1157s 1s/step - loss: 0.5788 - accuracy: 0.6887 - val_loss: 0.5449 - val_accuracy: 0.7142
# Epoch 24/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5550 - accuracy: 0.7062
# Epoch 24: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1157s 1s/step - loss: 0.5550 - accuracy: 0.7062 - val_loss: 0.5457 - val_accuracy: 0.7137
# Epoch 25/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5477 - accuracy: 0.7119
# Epoch 25: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1158s 1s/step - loss: 0.5477 - accuracy: 0.7119 - val_loss: 0.5273 - val_accuracy: 0.7298
# Epoch 26/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5342 - accuracy: 0.7215
# Epoch 26: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1157s 1s/step - loss: 0.5342 - accuracy: 0.7215 - val_loss: 0.5243 - val_accuracy: 0.7291
# Epoch 27/500
# 799/799 [==============================] - ETA: 0s - loss: 0.5677 - accuracy: 0.6964
# Epoch 27: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1158s 1s/step - loss: 0.5677 - accuracy: 0.6964 - val_loss: 0.5747 - val_accuracy: 0.6895
# Epoch 28/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6201 - accuracy: 0.6521
# Epoch 28: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1157s 1s/step - loss: 0.6201 - accuracy: 0.6521 - val_loss: 0.6729 - val_accuracy: 0.5875
# Epoch 29/500
# 799/799 [==============================] - ETA: 0s - loss: 1.8250 - accuracy: 0.5552
# Epoch 29: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1157s 1s/step - loss: 1.8250 - accuracy: 0.5552 - val_loss: 0.7129 - val_accuracy: 0.5818
# Epoch 30/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7498 - accuracy: 0.5574
# Epoch 30: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1157s 1s/step - loss: 0.7498 - accuracy: 0.5574 - val_loss: 0.6763 - val_accuracy: 0.5878
# Epoch 31/500
# 799/799 [==============================] - ETA: 0s - loss: 35.3789 - accuracy: 0.5175
# Epoch 31: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1157s 1s/step - loss: 35.3789 - accuracy: 0.5175 - val_loss: 0.7245 - val_accuracy: 0.5292
# Epoch 32/500
# 799/799 [==============================] - ETA: 0s - loss: 0.7461 - accuracy: 0.5453
# Epoch 32: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1158s 1s/step - loss: 0.7461 - accuracy: 0.5453 - val_loss: 0.6876 - val_accuracy: 0.5543
# Epoch 33/500
# 799/799 [==============================] - ETA: 0s - loss: 0.8354 - accuracy: 0.5404
# Epoch 33: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1158s 1s/step - loss: 0.8354 - accuracy: 0.5404 - val_loss: 0.6814 - val_accuracy: 0.5663
# Epoch 34/500
# 799/799 [==============================] - ETA: 0s - loss: 8.4808 - accuracy: 0.5289
# Epoch 34: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1157s 1s/step - loss: 8.4808 - accuracy: 0.5289 - val_loss: 0.6787 - val_accuracy: 0.5740
# Epoch 35/500
# 799/799 [==============================] - ETA: 0s - loss: 0.6801 - accuracy: 0.5709
# Epoch 35: val_loss did not improve from 0.29624
# 799/799 [==============================] - 1158s 1s/step - loss: 0.6801 - accuracy: 0.5709 - val_loss: 0.6746 - val_accuracy: 0.5760
# Training Time:  40605.694595098495 seconds

# %% [markdown]
# # Saving the model and training history

# %%
gru_model.save('GRU_Architecture_27_Features.h5')
np.save('GRU_history_27_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of GRU Network - 27 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of GRU Network - 27 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Reshaping X_test for GRU Model Evaluation

# %%
X_test_array = X_test
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
X_test_reshaped
# Out:
# array([[[ 0.46349357],
#         [ 0.36358773],
#         [ 3.37428511],
#         ...,
#         [ 0.54589363],
#         [ 0.76277015],
#         [-0.66724627]],
#
#        [[-3.12902325],
#         [-2.41096786],
#         [-4.83420457],
#         ...,
#         [-0.9701542 ],
#         [-2.61791719],
#         [-2.31896119]],
#
#        [[ 1.56338732],
#         [ 1.49249955],
#         [ 1.91877559],
#         ...,
#         [ 1.24833052],
#         [ 1.42932367],
#         [ 1.35848926]],
#
#        ...,
#
#        [[ 0.69592067],
#         [ 0.84838968],
#         [-0.60272074],
#         ...,
#         [ 0.65452093],
#         [ 1.35513171],
#         [ 1.22326088]],
#
#        [[ 2.17107007],
#         [ 2.96016373],
#         [ 3.46610892],
#         ...,
#         [ 2.15426389],
#         [ 2.52736704],
#         [ 1.96490661]],
#
#        [[ 0.16525652],
#         [-0.05828783],
#         [-0.23818711],
#         ...,
#         [-0.28802406],
#         [ 0.25460157],
#         [ 1.08541927]]])

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred_prob = gru_model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 227s 47ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = gru_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.86, Test loss: 0.30

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.87     77676
#            1       0.87      0.86      0.86     77614
#
#     accuracy                           0.86    155290
#    macro avg       0.87      0.86      0.86    155290
# weighted avg       0.87      0.86      0.86    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix GRU - 27 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.8649945263700174
# Precision: 0.8712011008452919
# Recall: 0.8565078465225346
# F1-score: 0.8637919944906087
# AUC-ROC: 0.9451764358931598

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
roc_data['GRU - 27'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()
